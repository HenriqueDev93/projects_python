# %% [markdown]
#  # Buscador de notícias
# <a href="https://pypi.org/project/GoogleNews/">API source</a>
#
# Objetivo: extrair dados de uma API do Google (GoogleNews) a fim de trazer notícias relacionadas com os dados informados pelo usuário.
#
# API: Application Programming Interface (Interface de Programação de Aplicação).
#
# #### Passo a passo:
#
# 1. Instalar e importar as bibliotecas necessárias para a função;
# 2. extrair dados de exemplo da API;
# 3. criar a função que automatiza a extração de dados da API.

# %% [markdown]
# ### 1. Instalar e importar as bibliotecas necessárias para a função:

# %% [markdown]
# pip install --upgrade GoogleNews

# %%
from GoogleNews import GoogleNews
import pandas as pd

# %% [markdown]
# ### 2. Extrair dados de exemplo da API:

# %%
googlenews = GoogleNews(encode='utf-8', lang='pt', period='90d')

googlenews.get_news('Data science')
result = googlenews.results(sort=True)
df = pd.DataFrame(result)
display(df)
# Out:
#                                                 title  desc            date  \
# 0               5 Free Courses to Master Data Science  None   5 horas atrás
# 1   Back to Basics Week 2: Database, SQL, Data Man...  None   7 horas atrás
# 2   Teaching Assistant (Statistics and Data Scienc...  None  13 horas atrás
# 3       Using ChatGPT to Help Land a Data Science Job  None    3 dias atrás
# 4   Senior Data Scientist (all genders) - Remote -...  None      13 de out.
# ..                                                ...   ...             ...
# 94  Post Doctoral Fellow - Wang Zizhuo Project, Sc...  None   11 dias atrás
# 95  5 Data science project Ideas for BSC/BCA students  None    5 dias atrás
# 96  IQVIA and Snowflake Your Solution for Data-Dri...  None   3 horas atrás
# 97  Data Science and AI Summit 2023: U-M Institute...  None   4 horas atrás
# 98  Pure Storage Drives Global Customer Breakthrou...  None   6 horas atrás
#
#     datetime                                               link  \
# 0        NaN  news.google.com/./articles/CBMiP2h0dHBzOi8vd3d...
# 1        NaN  news.google.com/./articles/CBMiZWh0dHBzOi8vd3d...
# 2        NaN  news.google.com/./articles/CBMibGh0dHBzOi8vd3d...
# 3        NaN  news.google.com/./articles/CBMiR2h0dHBzOi8vd3d...
# 4        NaN  news.google.com/./articles/CBMiOWh0dHBzOi8vd3d...
# ..       ...                                                ...
# 94       NaN  news.google.com/./articles/CBMifGh0dHBzOi8vd3d...
# 95       NaN  news.google.com/./articles/CBMiU2h0dHBzOi8vd3d...
# 96       NaN  news.google.com/./articles/CBMifGh0dHBzOi8vd3d...
# 97       NaN  news.google.com/./articles/CBMicmh0dHBzOi8vYW5...
# 98       NaN  news.google.com/./articles/CBMijgFodHRwczovL3d...
#
#                                                   img                   media  \
# 0   https://encrypted-tbn3.gstatic.com/faviconV2?u...               KDnuggets
# 1   https://encrypted-tbn3.gstatic.com/faviconV2?u...               KDnuggets
# 2   https://lh3.googleusercontent.com/GEnVlLptfD4t...  Times Higher Education
# 3   https://encrypted-tbn3.gstatic.com/faviconV2?u...               KDnuggets
# 4   https://encrypted-tbn3.gstatic.com/faviconV2?u...             Merck Group
# ..                                                ...                     ...
# 94  https://lh3.googleusercontent.com/GEnVlLptfD4t...  Times Higher Education
# 95  https://encrypted-tbn0.gstatic.com/faviconV2?u...       Analytics Insight
# 96  https://encrypted-tbn1.gstatic.com/faviconV2?u...                   IQVIA
# 97  https://encrypted-tbn2.gstatic.com/faviconV2?u...      Ann Arbor Observer
# 98  https://lh3.googleusercontent.com/kd4boDIAMrfL...             PR Newswire
#
#     site
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# ..   ...
# 94  None
# 95  None
# 96  None
# 97  None
# 98  None
#
# [99 rows x 8 columns]

# %% [markdown]
# ['pt', 'en', 'de', 'fr', 'es', 'ja']
# de: deutch
# fr: french
# es: espanish
# ja: japanese

# %% [markdown]
# ### 3. criar a função que automatiza a extração de dados da API:

# %%
# user_search:str = input('Qual item deseja buscar? ')
# user_lang:str = input('Em qual língua deseja pesquisar? ')
# user_period:str = input('Quantos dias anteriores? ')
# user_count:int = int(input('Quantos resultados deseja ver?'))

def search_news(user_lang, user_period, user_search, user_count):
    googlenews = GoogleNews(encode='utf-8', lang=user_lang, period=user_period+'d')
    googlenews.get_news(user_search)
    result = googlenews.results(sort=True)
    for _ in range(0, user_count):
        display(result)


search_news('pt', '80', 'carro', 10)
# Out:
# [{'title': 'Radar de velocidade também multa carro no rodízio?',
#   'desc': None,
#   'date': '2 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://autoesporte.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Autoesporte',
#   'site': None},
#  {'title': 'Quanto custa instalar ar-condicionado em um carro que não tem o equipamento?',
#   'desc': None,
#   'date': '6 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://autoesporte.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Autoesporte',
#   'site': None},
#  {'title': 'Motorista morre após carro aquaplanar e bater em outro veículo na BR-369, diz Samu',
#   'desc': None,
#   'date': '33 minutos atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Veja os 5 carros mais econômicos de até R$ 100 mil para trabalhar como Uber',
#   'desc': None,
#   'date': '3 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://autoesporte.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Autoesporte',
#   'site': None},
#  {'title': 'O triste fim do carro eletrificado no Brasil',
#   'desc': None,
#   'date': '1 hora atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMicGh0dHBzOi8vd3d3LmluZm9tb25leS5jb20uYnIvY29sdW5pc3Rhcy9vLW11bmRvLXNvYnJlLW11aXRhcy1yb2Rhcy9vLXRyaXN0ZS1maW0tZG8tY2Fycm8tZWxldHJpZmljYWRvLW5vLWJyYXNpbC_SAXRodHRwczovL3d3dy5pbmZvbW9uZXkuY29tLmJyL2NvbHVuaXN0YXMvby1tdW5kby1zb2JyZS1tdWl0YXMtcm9kYXMvby10cmlzdGUtZmltLWRvLWNhcnJvLWVsZXRyaWZpY2Fkby1uby1icmFzaWwvYW1wLw?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/ItNZqRYf9ym-u7VeBMjuHm5HeX0wRmZLHBc2BPeJ5jPCFbi6Xg1w5Nk35VLuaXQYWay9x8u_ZTA=s0-h14-rp',
#   'media': 'InfoMoney',
#   'site': None},
#  {'title': 'Ataque a carro-forte com troca de tiros deixa dois feridos e dinheiro espalhado na Rodovia Zeferino Vaz, em Cosmópolis',
#   'desc': None,
#   'date': '2 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Motorista bate carro em poste e três ficam feridos em Guarujá; VÍDEO',
#   'desc': None,
#   'date': '7 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'VÍDEO: Caminhão do Corpo de Bombeiros bate e arrasta carro em cruzamento de Cianorte',
#   'desc': None,
#   'date': '5 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Cada vez menos insetos estão atingindo o para-brisa do seu carro; entenda',
#   'desc': None,
#   'date': '9 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/lMYRJoH02W5WZPHKUuamgQ989vNMUalLAWRkTnc4IeARxSEgPlqc4OV6xn6XlswUGY6NAOHq=s0-h14-rp',
#   'media': 'UOL',
#   'site': None},
#  {'title': "Carro capota, 'voa' e derruba poste no Anel Rodoviário; VÍDEO",
#   'desc': None,
#   'date': '7 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Chery diz ter feito o carro mais aerodinâmico do mundo, mas não é verdade',
#   'desc': None,
#   'date': '3 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiSmh0dHBzOi8vbW90b3IxLnVvbC5jb20uYnIvbmV3cy82OTYwNDIvY2hlcnktY2Fycm8tbWFpcy1hZXJvZGluYW1pY28tbXVuZG8v0gFOaHR0cHM6Ly9tb3RvcjEudW9sLmNvbS5ici9uZXdzLzY5NjA0Mi9jaGVyeS1jYXJyby1tYWlzLWFlcm9kaW5hbWljby1tdW5kby9hbXAv?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/nvNi0WRmkXYdy_eWRs0He0fQJYd1ow3oYhAx9iTAMej4YifTgBqiqQdLi9lMJ6o4G0B5hOTSRA=s0-h14-rp',
#   'media': 'Motor1.com Brasil',
#   'site': None},
#  {'title': 'Modelo destrói carro avaliado em R$ 730 mil em momento de fúria pós-término',
#   'desc': None,
#   'date': '1 hora atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiemh0dHBzOi8vd3d3LmJhbmQudW9sLmNvbS5ici9lbnRyZXRlbmltZW50by9tb2RlbG8tZGVzdHJvaS1jYXJyby1hdmFsaWFkby1lbS1yLTczMC1lbS1tb21lbnRvLWRlLWZ1cmlhLXBvcy10ZXJtaW5vLTE2NjQ3MDUx0gF-aHR0cHM6Ly93d3cuYmFuZC51b2wuY29tLmJyL2VudHJldGVuaW1lbnRvL21vZGVsby1kZXN0cm9pLWNhcnJvLWF2YWxpYWRvLWVtLXItNzMwLWVtLW1vbWVudG8tZGUtZnVyaWEtcG9zLXRlcm1pbm8tMTY2NDcwNTEvYW1w?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/Ahw-X59vQhDWreOVyMIIuHFvPSXotymTXHWASKWyuNRcHBGZtRU99mM_TxkoY_Q4jS6RD2fDaQ=s0-h14-rp',
#   'media': 'Band Jornalismo',
#   'site': None},
#  {'title': 'Após beber três latas de cerveja, motorista bate em mureta e carro roda na pista da MG-050',
#   'desc': None,
#   'date': '7 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Guarda Municipal de Vitória recupera carro roubado na Mata da Praia',
#   'desc': None,
#   'date': '1 hora atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMib2h0dHBzOi8vd3d3LnZpdG9yaWEuZXMuZ292LmJyL25vdGljaWEvZ3VhcmRhLW11bmljaXBhbC1kZS12aXRvcmlhLXJlY3VwZXJhLWNhcnJvLXJvdWJhZG8tbmEtbWF0YS1kYS1wcmFpYS00OTIwONIBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.vitoria.es.gov.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Prefeitura de Vitória',
#   'site': None},
#  {'title': "Sertanejo George Henrique sofre acidente de carro e diz que 'bebida tem potencializado comportamentos negativos'",
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Bandidos arremessam cão de carro durante roubo, e bichinho morre dias depois; VÍDEO',
#   'desc': None,
#   'date': '11 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Mãe morre atropelada ao tentar evitar que carro descesse desgovernado com os filhos dentro',
#   'desc': None,
#   'date': '11 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Quais são os meus direitos ao comprar um carro usado?',
#   'desc': None,
#   'date': '5 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/d5sC9mxcK1X8HYowtxWTy4J2zFaKA3DtxWLD14jHWwOZapEEF3BIsa1anLBggpR3sezV3FJ6ZQ=s0-h14-rp',
#   'media': 'Portal do Trânsito',
#   'site': None},
#  {'title': 'Morre 5ª vítima de acidente envolvendo caminhão, duas motos e carro no interior de SP',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Carro roubado no Rio é encontrado no Alto',
#   'desc': None,
#   'date': '37 minutos atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiTGh0dHBzOi8vbmV0ZGlhcmlvLmNvbS5ici9ub3RpY2lhcy9jYXJyby1yb3ViYWRvLW5vLXJpby1lLWVuY29udHJhZG8tbm8tYWx0by_SAQA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://netdiario.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'O Diário de Teresópolis',
#   'site': None},
#  {'title': 'Motorista morre carbonizado em acidente com carro, caminhões e caminhonete na BR-153',
#   'desc': None,
#   'date': '2 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': '275 km/h: veja carro elétrico bater recorde andando de marcha à ré',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/tVbnq_sAAvvDqKXv1WNsta-vehuk1jzxAzTnJ0p1HKtjlw-cLz6s_mDFoPODTVfIjWVpLFY41Q=s0-h14-rp',
#   'media': 'Giz Brasil',
#   'site': None},
#  {'title': 'Carro bate de frente com caminhão na MGC-135 e motorista morre',
#   'desc': None,
#   'date': '11 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Mulheres são resgatadas após carro bater em caminhão, descer ribanceira e fica retorcido',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Primeira-dama de Agrestina é vista vandalizando carro após suposta confusão envolvendo o prefeito',
#   'desc': None,
#   'date': '10 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/HqhgDgCbF8iHRASmDYb4QQoybO6R0cc2VTcFR6bbGO1aG_YOFU2tbSrn3ndwj6JamVbo8hraUfM=s0-h14-rp',
#   'media': 'JC Online',
#   'site': None},
#  {'title': 'Motorista de carro fica gravemente ferido em acidente com caminhão na BR-262',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Por que Kwid e Mobi devem ser os últimos carros baratos do Brasil',
#   'desc': None,
#   'date': '9 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMigQFodHRwczovL3d3dy51b2wuY29tLmJyL2NhcnJvcy9jb2x1bmFzL3BhdWxhLWdhbWEvMjAyMy8xMS8xMy9wb3ItcXVlLWt3aWQtZS1tb2JpLWRldmVtLXNlci1vcy11bHRpbW9zLWNhcnJvcy1iYXJhdG9zLWRvLWJyYXNpbC5odG3SAQA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/u3y49tHujOwjZNHAOIqkAYdyOrh9eKg4Z0HjUvvvD-3YvvH4oCDpK-GviYp1r_CPDAtPQjW4_Q=s0-h14-rp',
#   'media': 'UOL Carros',
#   'site': None},
#  {'title': 'Criança de 9 anos fica ferida após ser atropelada por carro conduzido por adolescente, no DF',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Júri absolve acusada de jogar carro em cima de moto e matar marido e amante, em Álvares Machado',
#   'desc': None,
#   'date': '1 hora atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Mulher pula de carro para fugir de tentativa de abuso sexual de motorista por aplicativo na Bahia',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'VÍDEO: Caminhão tomba em curva da BR-376 e bate em carro que sinalizava outro acidente no mesmo local',
#   'desc': None,
#   'date': '3 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Carro avança preferencial e é atingido por ônibus do transporte público em Maringá, dizem Bombeiros',
#   'desc': None,
#   'date': '4 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Homem morre após ser baleado dentro de carro em estacionamento de Lorena, SP',
#   'desc': None,
#   'date': '9 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'VÍDEO: Carro desgovernado em alta velocidade atinge 6 veículos, quase atropela estudantes e capota no ES',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Após batida em cruzamento, carro tomba em Betim; motorista sofreu ...',
#   'desc': None,
#   'date': '1 hora atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMifWh0dHBzOi8vd3d3Lm90ZW1wby5jb20uYnIvby10ZW1wby1iZXRpbS9hcG9zLWJhdGlkYS1lbS1jcnV6YW1lbnRvLWNhcnJvLXRvbWJhLWVtLWJldGltLW1vdG9yaXN0YS1zb2ZyZXUtZXNjb3JpYWNvZXMtMS4zMjczOTgz0gEA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/WgHyKWDvhC7NW5Sdn9Ormc4LhTliVtI6FZZo4rNYKOpDsuOu3PbBjKmeiTJMNxXlFP2xsUoJ=s0-h14-rp',
#   'media': 'O Tempo',
#   'site': None},
#  {'title': 'Pastor evangélico está entre vítimas de chacina em carro na Bahia; polícia suspeita de disputa entre famílias rivais',
#   'desc': None,
#   'date': '6 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Esquenta Rent Friday! Aluguel de carro até 60% OFF mais cupom ...',
#   'desc': None,
#   'date': '9 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiS2h0dHBzOi8vd3d3Lm1lbGhvcmVzZGVzdGlub3MuY29tLmJyL3Byb21vY2FvL3JlbnQtZnJpZGF5LWFsdWd1ZWwtY2Fycm8tMjAyM9IBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/kic3qzq-RhhehtN4pCRxNQBwIH_we-DmwenUT5zEHWh9j0s3TxP0tEqNRJ7U9VP0FX-pW_Kf1HA=s0-h14-rp',
#   'media': 'Melhores Destinos',
#   'site': None},
#  {'title': 'Moto vai parar embaixo de carro após colisão na av. Pedro Álvares Cabral, em Belém',
#   'desc': None,
#   'date': '9 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Militar da Marinha é ferido com arma branca e tem carro atingido por tiro no Farol de Mãe Luiza em Natal',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Bandidos com armamento pesado explodem carro-forte e deixam feridos em São Paulo',
#   'desc': None,
#   'date': '1 hora atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/Ahw-X59vQhDWreOVyMIIuHFvPSXotymTXHWASKWyuNRcHBGZtRU99mM_TxkoY_Q4jS6RD2fDaQ=s0-h14-rp',
#   'media': 'Band Jornalismo',
#   'site': None},
#  {'title': 'Motorista perde controle de direção e carro vai parar no telhado de estabelecimento em Franca, SP',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Motociclista morre ao bater de frente com carro em rodovia de Novo Horizonte',
#   'desc': None,
#   'date': '1 hora atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Análise: Afinal, Imposto de Importação para carro elétrico promove ou não a produção local?',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/P3V4S0cgRaO5YlUW9Jv-mXq2s77T8dYdrVgsakXMOshPSvQhyn7kBbadEZ165BZtbbRigcFR=s0-h14-rp',
#   'media': 'Valor Econômico',
#   'site': None},
#  {'title': 'PRF recupera carro clonado na BR 070, em Ceilândia',
#   'desc': None,
#   'date': '7 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMid2h0dHBzOi8vd3d3Lmdvdi5ici9wcmYvcHQtYnIvbm90aWNpYXMvZXN0YWR1YWlzL2Rpc3RyaXRvLWZlZGVyYWwvMjAyMy9wcmYtcmVjdXBlcmEtY2Fycm8tY2xvbmFkby1uYS1ici0wNzAtZW0tY2VpbGFuZGlh0gEA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.gov.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'GOV.BR',
#   'site': None},
#  {'title': 'Nova moto elétrica tem bagageiro maior que porta-malas de carro compacto',
#   'desc': None,
#   'date': '36 minutos atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMihAFodHRwczovL29saGFyZGlnaXRhbC5jb20uYnIvMjAyMy8xMS8xMy9jYXJyb3MtZS10ZWNub2xvZ2lhL25vdmEtbW90by1lbGV0cmljYS10ZW0tYmFnYWdlaXJvLW1haW9yLXF1ZS1wb3J0YS1tYWxhcy1kZS1jYXJyby1jb21wYWN0by_SAYgBaHR0cHM6Ly9vbGhhcmRpZ2l0YWwuY29tLmJyLzIwMjMvMTEvMTMvY2Fycm9zLWUtdGVjbm9sb2dpYS9ub3ZhLW1vdG8tZWxldHJpY2EtdGVtLWJhZ2FnZWlyby1tYWlvci1xdWUtcG9ydGEtbWFsYXMtZGUtY2Fycm8tY29tcGFjdG8vYW1wLw?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/bOTBDH0sO4-6qXf4I6J8FDbgOuPiwXz2jvIscOkLYJyXacBDWNV-2aAwZF0S4EgVo0vSh-rqTg=s0-h14-rp',
#   'media': 'Olhar Digital',
#   'site': None},
#  {'title': 'Carro pega fogo no centro de Curitiba; é o segundo caso em uma ...',
#   'desc': None,
#   'date': '4 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiaWh0dHBzOi8vY2JuY3VyaXRpYmEuY29tLmJyL21hdGVyaWFzL2NhcnJvLXBlZ2EtZm9nby1uby1jZW50cm8tZGUtY3VyaXRpYmEtZS1vLXNlZ3VuZG8tY2Fzby1lbS11bWEtc2VtYW5hL9IBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://cbncuritiba.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'CBN Curitiba',
#   'site': None},
#  {'title': 'Prefeito de Itatiaia se envolve em acidente de carro em Resende',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Carro bate na traseira de outro veículo e capota em BH',
#   'desc': None,
#   'date': '10 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/DSHeva0wVCWvg3HHoAiaErhQTxoN4BuaVXRHtjRjvf2T0txatyfdu7CAozIrMDpHP9xmtjOM=s0-h14-rp',
#   'media': 'Itatiaia',
#   'site': None},
#  {'title': 'Avião invade pista e bate de frente com carro no Texas, EUA',
#   'desc': None,
#   'date': '7 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/aji1rL2KcFxFwL_-VrIb382CsMO2O9pqVMuEH2ouo6ML7jemYTwH0fcPrgSE6AybBzmlvmZs=s0-h14-rp',
#   'media': 'TV Cultura',
#   'site': None},
#  {'title': 'F1: Ocon nega que alterações no carro da Alpine tenham favorecido Gasly',
#   'desc': None,
#   'date': '4 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/ey1xCK7CzFPT73fdfsAqcfS2c7APblC5L-LDVqmbi8CDLU5BG_2t3L_vT8BDCcVHSh9xfs0Y6O8=s0-h14-rp',
#   'media': 'F1Mania.net',
#   'site': None},
#  {'title': "Jogador do Sevilla lamenta morte em acidente de carro de sobrinho que também era atleta: 'Tragédia'",
#   'desc': None,
#   'date': '9 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Carro é roubado e criança de 4 anos que estava dentro do veículo é abandonada sozinha no meio da rua no ES',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Jogador da NBA é atropelado por carro e fratura costela',
#   'desc': None,
#   'date': '5 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/hMltWRpxC8ei__O0GFaynv3DH7HiUNl22eziSW7rZXJY5R20_ati4fk7VBfZ9UhQzJj1bbAp7w=s0-h14-rp',
#   'media': 'UOL Esporte',
#   'site': None},
#  {'title': 'Ciclista morre após colidir com carro na rodovia Fernando Guilhon, em Santarém',
#   'desc': None,
#   'date': '10 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Carro de Juscelino Kubitschek ganha restauração e encanta ...',
#   'desc': None,
#   'date': '1 hora atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiiAFodHRwczovL25vdGljaWFzLnI3LmNvbS9icmFzaWxpYS9iYWxhbmNvLWdlcmFsLWRmL3ZpZGVvcy9jYXJyby1kZS1qdXNjZWxpbm8ta3ViaXRzY2hlay1nYW5oYS1yZXN0YXVyYWNhby1lLWVuY2FudGEtYnJhc2lsaWVuc2VzLTEzMTEyMDIz0gEA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://noticias.r7.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'R7.com',
#   'site': None},
#  {'title': 'Enem 2023: candidatos chegam a gastar R$ 300 com carro de aplicativo para fazer os dois dias de prova',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://oglobo.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'O Globo',
#   'site': None},
#  {'title': 'Acidente entre carro e ônibus deixa ao menos dois mortos no Vale do Aço',
#   'desc': None,
#   'date': '12 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/WgHyKWDvhC7NW5Sdn9Ormc4LhTliVtI6FZZo4rNYKOpDsuOu3PbBjKmeiTJMNxXlFP2xsUoJ=s0-h14-rp',
#   'media': 'O Tempo',
#   'site': None},
#  {'title': 'Carro capota após colisão na zona norte de Porto Alegre',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/rvpL9jCZALl2R8nZU8gJNK5nlTpUlwMVDyLfZNkHPudWj5EUXcC9iodFWc0EbmxlSxj-m4Nwrg=s0-h14-rp',
#   'media': 'Terra',
#   'site': None},
#  {'title': 'Homem e mulher morrem em acidente entre carro e carreta na BR-393, em Três Rios',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Idosa de 85 anos sofre acidente grave em carro que capotou próximo a ponta de Pedra, em Santarém',
#   'desc': None,
#   'date': '22 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Carro oficial usado por neta de Biden foi alvo de tentativa de ataque nos EUA',
#   'desc': None,
#   'date': '2 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/P2NOA6GHndbh3ySTAZ6u8Df_3ndIAbv0Aed7cMsqWkwLC4UWvWdAtQDKg_AI4EK2lZ3vDW_Jug=s0-h14-rp',
#   'media': 'Gazeta do Povo',
#   'site': None},
#  {'title': 'TJ/DF: Município indenizará homem que teve carro atingido por árvore',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/CTTskvqJeTUKxyUYvN3kOh8GM2bydQ4KOJ7RPtkkFXDCUknKLYRMMZ1mveBvgwbGCuiYRnM7dQ=s0-h14-rp',
#   'media': 'Migalhas',
#   'site': None},
#  {'title': 'De novo? Peões são acordados com carro de som em A Fazenda',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/hM2il9eWxAKots7Wv97UYsitg3KOuTkYqCq5jrJiOwnCNeYmTe2Prfs7Gxopp15QlM6AQnd59zI=s0-h14-rp',
#   'media': 'Splash',
#   'site': None},
#  {'title': 'Companhia aérea oferecerá carro elétrico com motorista para ...',
#   'desc': None,
#   'date': '4 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMieGh0dHBzOi8vd3d3LmNubmJyYXNpbC5jb20uYnIvZWNvbm9taWEvY29tcGFuaGlhLWFlcmVhLW9mZXJlY2VyYS1jYXJyby1lbGV0cmljby1jb20tbW90b3Jpc3RhLXBhcmEtZW1iYXJxdWUtZW0tY29uZ29uaGFzL9IBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/Rk0auidG4eKgBCihgyWQJXoCtVvpn0O2O6J_M8xvl2citf6OXdFKkGxqGCRCT9SQqo5ANBmQ8Q=s0-h14-rp',
#   'media': 'CNN Brasil',
#   'site': None},
#  {'title': 'Vídeo: carro fica totalmente destruído após pegar fogo em rua do DF',
#   'desc': None,
#   'date': '5 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/8tQQPht1E8Ono8ZGOd7d0muqcpwnSyrFjsYTvCkaTfYnaAKjvcKSl-udvLKJq-1TPBlcEblWPw=s0-h14-rp',
#   'media': 'Metrópoles',
#   'site': None},
#  {'title': 'Vídeo mostra momento em que carro invade bar e atropela cliente ...',
#   'desc': None,
#   'date': '7 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiamh0dHBzOi8vbWFyaWxpYW5vdGljaWEuY29tLmJyL3ZpZGVvLW1vc3RyYS1tb21lbnRvLWVtLXF1ZS1jYXJyby1pbnZhZGUtYmFyLWUtYXRyb3BlbGEtY2xpZW50ZS1uYS16b25hLXN1bC_SAQA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://marilianoticia.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Marília Notícia',
#   'site': None},
#  {'title': 'Como tirar cheiro de cigarro e outros odores do interior do carro?',
#   'desc': None,
#   'date': '7 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://autoesporte.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Autoesporte',
#   'site': None},
#  {'title': 'Homem é condenado a pagar multa por usar carro alugado em ...',
#   'desc': None,
#   'date': '8 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiYGh0dHBzOi8vd3d3LmNvbmp1ci5jb20uYnIvMjAyMy1ub3YtMDUvY2xpZW50ZS1jb25kZW5hZG8tcGFnYXItbXVsdGEtdXNhci1jYXJyby1hbHVnYWRvLWF1dG9kcm9tb9IBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.conjur.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Conjur',
#   'site': None},
#  {'title': 'Motociclista morre em acidente com carro em Volta Redonda',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Motorista de aplicativo é encontrado em porta-malas de carro após assalto em Nova Iguaçu',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Ônibus de Lajeado colide com carro na BR-386, em Triunfo - Grupo ...',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiZ2h0dHBzOi8vZ3J1cG9haG9yYS5uZXQuYnIvY29udGV1ZG9zLzIwMjMvMTEvMTMvb25pYnVzLWRlLWxhamVhZG8tY29saWRlLWNvbS1jYXJyby1uYS1ici0zODYtZW0tdHJpdW5mby_SAQA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/gxIX1ZcKAUtz_IaVjoQryTHagQ7YDBVkOqe4WcZNsYNSPBM5ST3uy78lh_1Nd0Z-zyn_WAC4x_o=s0-h14-rp',
#   'media': 'A Hora',
#   'site': None},
#  {'title': 'Carro incendeia e três pessoas morrem após baterem de frente com outro carro na PRC-158',
#   'desc': None,
#   'date': '8 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'A onda do carro elétrico chinês se espalha',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/P3V4S0cgRaO5YlUW9Jv-mXq2s77T8dYdrVgsakXMOshPSvQhyn7kBbadEZ165BZtbbRigcFR=s0-h14-rp',
#   'media': 'Valor Econômico',
#   'site': None},
#  {'title': 'Óleo do carro: como saber qual é o lubrificante correto para usar',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/rvpL9jCZALl2R8nZU8gJNK5nlTpUlwMVDyLfZNkHPudWj5EUXcC9iodFWc0EbmxlSxj-m4Nwrg=s0-h14-rp',
#   'media': 'Terra',
#   'site': None},
#  {'title': 'CUIDADO: VOCÊ PODE ESTAR SENDO ROUBADO NA HORA DE ...',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMibGh0dHBzOi8vYXV0b2VudHVzaWFzdGFzLmNvbS5ici8yMDIzLzExL2N1aWRhZG8tdm9jZS1wb2RlLWVzdGFyLXNlbmRvLXJvdWJhZG8tbmEtaG9yYS1kZS1hYmFzdGVjZXItc2V1LWNhcnJvL9IBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://autoentusiastas.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Autoentusiastas',
#   'site': None},
#  {'title': 'Ocon admite que já testa carro de 2024 da Alpine no simulador',
#   'desc': None,
#   'date': '14 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMieWh0dHBzOi8vd3d3LmdyYW5kZXByZW1pby5jb20uYnIvZjEvbm90aWNpYXMvZXN0ZWJhbi1vY29uLWFkbWl0ZS1qYS10ZXN0YS1jYXJyby0yMDI0LWFscGluZS1zaW11bGFkb3ItcHJlY2lzYW1vcy1tZWxob3Jhci_SAX1odHRwczovL3d3dy5ncmFuZGVwcmVtaW8uY29tLmJyL2YxL25vdGljaWFzL2VzdGViYW4tb2Nvbi1hZG1pdGUtamEtdGVzdGEtY2Fycm8tMjAyNC1hbHBpbmUtc2ltdWxhZG9yLXByZWNpc2Ftb3MtbWVsaG9yYXIvYW1wLw?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/cmn-Nebb5xHBmgh43GE5RrofT__XatnVhJ5wSbY9rm9GQ_rS_JZzU60iQWIBPwOjzqPABQGNkQ=s0-h14-rp',
#   'media': 'Grande Prêmio',
#   'site': None},
#  {'title': 'Jovem capota carro e colide contra poste, na BR-101',
#   'desc': None,
#   'date': '10 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiU2h0dHBzOi8vcG9ydGFsbGl0b3JhbHN1bC5jb20uYnIvam92ZW0tY2Fwb3RhLWNhcnJvLWUtY29saWRlLWNvbnRyYS1wb3N0ZS1uYS1ici0xMDEv0gEA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://portallitoralsul.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Portal Litoral Sul',
#   'site': None},
#  {'title': 'Preço da bateria do carro elétrico está caindo mais rápido que o esperado',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiUGh0dHBzOi8vaW5zaWRlZXZzLnVvbC5jb20uYnIvbmV3cy82OTUzMjgvcHJlY29zLWJhdGVyaWFzLWNhcnJvcy1lbGV0cmljb3MtcXVlZGEv0gFUaHR0cHM6Ly9pbnNpZGVldnMudW9sLmNvbS5ici9uZXdzLzY5NTMyOC9wcmVjb3MtYmF0ZXJpYXMtY2Fycm9zLWVsZXRyaWNvcy1xdWVkYS9hbXAv?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/KJanXxEjQ7NHA3xMRL-O4qYITMcFEEpniUF3dzPpp0uNoOPD_rjY6vwCQCwNvKV6fVFsBrKr=s0-h14-rp',
#   'media': 'InsideEVs Brasil',
#   'site': None},
#  {'title': 'Acidente entre caminhão e carro interdita duas faixas e gera congestionamento na Dutra em São José',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': "Casal 'transforma' carro em 'trenó' para garantir diversão de passageiros em corridas de aplicativo: 'Experiência diferenciada'",
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Carro do Ano 2024: conheça os jurados',
#   'desc': None,
#   'date': '7 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://autoesporte.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Autoesporte',
#   'site': None},
#  {'title': 'Motociclista é socorrido com fratura exposta em acidente entre moto e carro na avenida Jasmim, em Santarém',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Regis Danese conta detalhes do acidente de carro: "Lembrei do Cristiano Araújo"',
#   'desc': None,
#   'date': '11 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/rvpL9jCZALl2R8nZU8gJNK5nlTpUlwMVDyLfZNkHPudWj5EUXcC9iodFWc0EbmxlSxj-m4Nwrg=s0-h14-rp',
#   'media': 'Terra',
#   'site': None},
#  {'title': 'Motociclista morre após dirigir na contramão e bater contra carro, em avenida na zona norte de SP',
#   'desc': None,
#   'date': '10 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/._YW1w?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://noticias.r7.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'R7.com',
#   'site': None},
#  {'title': 'MG: Advogada de 35 anos morre e 3 ficam feridos em grave acidente de carro',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://noticias.uol.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'UOL Confere',
#   'site': None},
#  {'title': 'Grave acidente entre carro e ônibus que transportava trabalhadores rurais deixa um morto e feridos na MG-188',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Jovem fica ferido em batida entre carro e moto na avenida do Contorno',
#   'desc': None,
#   'date': '12 horas atrás',
#   'datetime': nan,
# ...
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Ônibus de Lajeado colide com carro na BR-386, em Triunfo - Grupo ...',
#   'desc': None,
#   'date': '8 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiZ2h0dHBzOi8vZ3J1cG9haG9yYS5uZXQuYnIvY29udGV1ZG9zLzIwMjMvMTEvMTMvb25pYnVzLWRlLWxhamVhZG8tY29saWRlLWNvbS1jYXJyby1uYS1ici0zODYtZW0tdHJpdW5mby_SAQA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/gxIX1ZcKAUtz_IaVjoQryTHagQ7YDBVkOqe4WcZNsYNSPBM5ST3uy78lh_1Nd0Z-zyn_WAC4x_o=s0-h14-rp',
#   'media': 'A Hora',
#   'site': None},
#  {'title': 'Carro incendeia e três pessoas morrem após baterem de frente com outro carro na PRC-158',
#   'desc': None,
#   'date': '8 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'A onda do carro elétrico chinês se espalha',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/P3V4S0cgRaO5YlUW9Jv-mXq2s77T8dYdrVgsakXMOshPSvQhyn7kBbadEZ165BZtbbRigcFR=s0-h14-rp',
#   'media': 'Valor Econômico',
#   'site': None},
#  {'title': 'Óleo do carro: como saber qual é o lubrificante correto para usar',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/rvpL9jCZALl2R8nZU8gJNK5nlTpUlwMVDyLfZNkHPudWj5EUXcC9iodFWc0EbmxlSxj-m4Nwrg=s0-h14-rp',
#   'media': 'Terra',
#   'site': None},
#  {'title': 'CUIDADO: VOCÊ PODE ESTAR SENDO ROUBADO NA HORA DE ...',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMibGh0dHBzOi8vYXV0b2VudHVzaWFzdGFzLmNvbS5ici8yMDIzLzExL2N1aWRhZG8tdm9jZS1wb2RlLWVzdGFyLXNlbmRvLXJvdWJhZG8tbmEtaG9yYS1kZS1hYmFzdGVjZXItc2V1LWNhcnJvL9IBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://autoentusiastas.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Autoentusiastas',
#   'site': None},
#  {'title': 'Ocon admite que já testa carro de 2024 da Alpine no simulador',
#   'desc': None,
#   'date': '14 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMieWh0dHBzOi8vd3d3LmdyYW5kZXByZW1pby5jb20uYnIvZjEvbm90aWNpYXMvZXN0ZWJhbi1vY29uLWFkbWl0ZS1qYS10ZXN0YS1jYXJyby0yMDI0LWFscGluZS1zaW11bGFkb3ItcHJlY2lzYW1vcy1tZWxob3Jhci_SAX1odHRwczovL3d3dy5ncmFuZGVwcmVtaW8uY29tLmJyL2YxL25vdGljaWFzL2VzdGViYW4tb2Nvbi1hZG1pdGUtamEtdGVzdGEtY2Fycm8tMjAyNC1hbHBpbmUtc2ltdWxhZG9yLXByZWNpc2Ftb3MtbWVsaG9yYXIvYW1wLw?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/cmn-Nebb5xHBmgh43GE5RrofT__XatnVhJ5wSbY9rm9GQ_rS_JZzU60iQWIBPwOjzqPABQGNkQ=s0-h14-rp',
#   'media': 'Grande Prêmio',
#   'site': None},
#  {'title': 'Jovem capota carro e colide contra poste, na BR-101',
#   'desc': None,
#   'date': '10 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiU2h0dHBzOi8vcG9ydGFsbGl0b3JhbHN1bC5jb20uYnIvam92ZW0tY2Fwb3RhLWNhcnJvLWUtY29saWRlLWNvbnRyYS1wb3N0ZS1uYS1ici0xMDEv0gEA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://portallitoralsul.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Portal Litoral Sul',
#   'site': None},
#  {'title': 'Preço da bateria do carro elétrico está caindo mais rápido que o esperado',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiUGh0dHBzOi8vaW5zaWRlZXZzLnVvbC5jb20uYnIvbmV3cy82OTUzMjgvcHJlY29zLWJhdGVyaWFzLWNhcnJvcy1lbGV0cmljb3MtcXVlZGEv0gFUaHR0cHM6Ly9pbnNpZGVldnMudW9sLmNvbS5ici9uZXdzLzY5NTMyOC9wcmVjb3MtYmF0ZXJpYXMtY2Fycm9zLWVsZXRyaWNvcy1xdWVkYS9hbXAv?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/KJanXxEjQ7NHA3xMRL-O4qYITMcFEEpniUF3dzPpp0uNoOPD_rjY6vwCQCwNvKV6fVFsBrKr=s0-h14-rp',
#   'media': 'InsideEVs Brasil',
#   'site': None},
#  {'title': 'Acidente entre caminhão e carro interdita duas faixas e gera congestionamento na Dutra em São José',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': "Casal 'transforma' carro em 'trenó' para garantir diversão de passageiros em corridas de aplicativo: 'Experiência diferenciada'",
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Carro do Ano 2024: conheça os jurados',
#   'desc': None,
#   'date': '7 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://autoesporte.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Autoesporte',
#   'site': None},
#  {'title': 'Motociclista é socorrido com fratura exposta em acidente entre moto e carro na avenida Jasmim, em Santarém',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Regis Danese conta detalhes do acidente de carro: "Lembrei do Cristiano Araújo"',
#   'desc': None,
#   'date': '11 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/rvpL9jCZALl2R8nZU8gJNK5nlTpUlwMVDyLfZNkHPudWj5EUXcC9iodFWc0EbmxlSxj-m4Nwrg=s0-h14-rp',
#   'media': 'Terra',
#   'site': None},
#  {'title': 'Motociclista morre após dirigir na contramão e bater contra carro, em avenida na zona norte de SP',
#   'desc': None,
#   'date': '10 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/._YW1w?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://noticias.r7.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'R7.com',
#   'site': None},
#  {'title': 'MG: Advogada de 35 anos morre e 3 ficam feridos em grave acidente de carro',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://noticias.uol.com.br&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'UOL Confere',
#   'site': None},
#  {'title': 'Grave acidente entre carro e ônibus que transportava trabalhadores rurais deixa um morto e feridos na MG-188',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Jovem fica ferido em batida entre carro e moto na avenida do Contorno',
#   'desc': None,
#   'date': '12 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/._YW1w?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/DSHeva0wVCWvg3HHoAiaErhQTxoN4BuaVXRHtjRjvf2T0txatyfdu7CAozIrMDpHP9xmtjOM=s0-h14-rp',
#   'media': 'Itatiaia',
#   'site': None},
#  {'title': 'Olivia Wilde e Chris Rock saem juntinhos no mesmo carro de aniversário de DiCaprio e acendem especulações de affair',
#   'desc': None,
#   'date': '34 minutos atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://revistamonet.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'Revista Monet',
#   'site': None},
#  {'title': 'Motoristas consideram rodízio ao escolher placa na compra do carro, revela pesquisa',
#   'desc': None,
#   'date': '8 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/zFy5G1XjocQHVGrnc_HVB3YljjYM4dMJLPTuMlRLNK6SeQOmV0kPfAbv4UMOA7-An7HM9SIY1f8=s0-h14-rp',
#   'media': 'Valor Investe',
#   'site': None},
#  {'title': 'Caminhonete e carro colidem e passageira necessita de ...',
#   'desc': None,
#   'date': '6 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMikgFodHRwczovL3d3dy5jbGljY2FtYXF1YS5jb20uYnIvbm90aWNpYXMvdHJhbnNpdG8vYWNpZGVudGVzL2NhbWluaG9uZXRlLWUtY2Fycm8tY29saWRlbS1lLXBhc3NhZ2VpcmEtbmVjZXNzaXRhLWRlLWF0ZW5kaW1lbnRvLW5vLWNlbnRyby1kZS1jYW1hcXVhL9IBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/XTu_lSy7Ep1NApRmOdjgcy3DWUnr2g_u9GsyZ2Ry9hme7KCyqxIsrbqZ0W0FkdVzdDdelKsmP4c=s0-h14-rp',
#   'media': 'Clic Camaquã',
#   'site': None},
#  {'title': 'Suspeitos de roubar carro e fazer família refém são mortos em confronto com a polícia em MT',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Jovem de 19 anos morre após carro capotar em rodovia de Minas',
#   'desc': None,
#   'date': 'Ontem',
#   'datetime': nan,
#   'link': 'news.google.com/.?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/WgHyKWDvhC7NW5Sdn9Ormc4LhTliVtI6FZZo4rNYKOpDsuOu3PbBjKmeiTJMNxXlFP2xsUoJ=s0-h14-rp',
#   'media': 'O Tempo',
#   'site': None},
#  {'title': 'Toyota Mirai é o carro a hidrogênio que quer aproveitar nosso etanol',
#   'desc': None,
#   'date': '4 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMibGh0dHBzOi8vcXVhdHJvcm9kYXMuYWJyaWwuY29tLmJyL3Rlc3Rlcy90b3lvdGEtbWlyYWktZS1vLWNhcnJvLWEtaGlkcm9nZW5pby1xdWUtcXVlci1hcHJvdmVpdGFyLW5vc3NvLWV0YW5vbNIBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/ZTPcnkIMLqAIuMiYjqt6DT5kSIORv7k70fBcIixc7NHivrnPcvpfOT2Tiu_mhuKiBeiNMnM2=s0-h14-rp',
#   'media': 'Quatro Rodas',
#   'site': None},
#  {'title': 'Carro pega fogo em garagem de prédio e moradores são retirados de edifício em Bom Despacho; VÍDEO',
#   'desc': None,
#   'date': '2 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Criança e PM mortos, tiroteios e carro incendiado: fim de semana é marcado por violência na RMF',
#   'desc': None,
#   'date': '3 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/F_kSgbFDQ-YmXHT8_LD9kcQA4DFJ5GDmjut7omisULFclm75p2Qgqwu9UoP6bN_SKiURov74z-c=s0-h14-rp',
#   'media': 'Diário do Nordeste',
#   'site': None},
#  {'title': 'Sob chuva, motorista perde o controle da direção e carro atinge barranco na Rodovia José Batista de Souza',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Vídeo resgata notícia antiga e engana sobre interrupção da ...',
#   'desc': None,
#   'date': '3 horas atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMigwFodHRwczovL3d3dy5uc2N0b3RhbC5jb20uYnIvbm90aWNpYXMvdmlkZW8tcmVzZ2F0YS1ub3RpY2lhLWFudGlnYS1lLWVuZ2FuYS1zb2JyZS1pbnRlcnJ1cGNhby1kYS1vcGVyYWNhby1jYXJyby1waXBhLW5vLWdvdmVybm8tbHVsYdIBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/JNq_vfi7BykdcdwkVQxGfDX4KZ5S2nY0IUh8KWOzqdq8mv0GJZD9b7yyvCg_kNPelH8dyIUB=s0-h14-rp',
#   'media': 'NSC Total',
#   'site': None},
#  {'title': 'Huawei lança carro elétrico para competir com Tesla',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/./articles/CBMiWmh0dHBzOi8vd3d3LmNubmJyYXNpbC5jb20uYnIvZWNvbm9taWEvaHVhd2VpLWxhbmNhLWNhcnJvLWVsZXRyaWNvLXBhcmEtY29tcGV0aXItY29tLXRlc2xhL9IBAA?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://lh3.googleusercontent.com/Rk0auidG4eKgBCihgyWQJXoCtVvpn0O2O6J_M8xvl2citf6OXdFKkGxqGCRCT9SQqo5ANBmQ8Q=s0-h14-rp',
#   'media': 'CNN Brasil',
#   'site': None},
#  {'title': 'Dois homens suspeitos de roubar carro são presos depois de caírem com veículo dentro de córrego',
#   'desc': None,
#   'date': '3 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None},
#  {'title': 'Motorista passa mal, carro vai parar em cima de mureta e quase cai de ponte em Franca, SP',
#   'desc': None,
#   'date': '5 dias atrás',
#   'datetime': nan,
#   'link': 'news.google.com/....?hl=pt-BR&gl=BR&ceid=BR%3Apt-419',
#   'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://g1.globo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#   'media': 'G1',
#   'site': None}]
