# %% [markdown]
# # Desenvolver um gráfico de temperaturas médias por cidade
#
# <a href="https://portal.inmet.gov.br/dadoshistoricos">Source link</a>
#
# Com base em um banco de dados do Instituto Nacional de Meteorologia, o objetivo é criar um código que consiga extrair os dados fornecidos e transformá-los em um gráfico, de forma dinâmica.
# Estados escolhidos:
# - Minas Gerais;
# - São Paulo;
# - Rio de Janeiro;
# - Distrito Federal;
# - Goiás e;
# - Bahia.
#
# ### Passo-a-passo:
#
# 1. Importar as bibliotecas necessárias para o código;
# 2. selecionar os estados informados acima;
# 3. isolar os nomes das cidades que constam no banco de dados;
# 4. importar o banco de dados;
# 5. tratar o banco de dados;
# 6. agrupar os dados por mês;
# 7. tratar os nomes das linhas, definindo o mês em questão;
# 8. criar e exibir o gráfico interativo.

# %% [markdown]
# ##### 1. Importar as bibliotecas necessárias para o código:

# %%
import os
import pandas as pd
import re
import plotly.graph_objects as go

# %% [markdown]
# ##### Passos 2 e 3 - Selecionar os estados informados, isolar os nomes das cidades que constam no banco de dados:

# %%
[cities_mg, cities_rj, cities_sp, cities_go, cities_df, cities_ba] = [dict(), dict(), dict(), dict(), dict(), dict()]
for yr in range(2003, 2024):
    yr_list = os.listdir(f'assets/{yr}/')
    i = 0
    j = 0
    for _ in range(0, len(yr_list)):
        if yr_list[i][:11] == 'INMET_SE_MG':
            cities_mg[f'{yr}_{j}'] = (yr_list[i][17:-28])
            j+=1
        if yr_list[i][:11] == 'INMET_SE_SP':
            cities_sp[f'{yr}_{j}'] = (yr_list[i][17:-28])
            j+=1
        if yr_list[i][:11] == 'INMET_SE_RJ':
            cities_rj[f'{yr}_{j}'] = (yr_list[i][17:-28])
            j+=1
        if yr_list[i][:11] == 'INMET_CO_DF':
            cities_df[f'{yr}_{j}'] = (yr_list[i][17:-28])
            j+=1
        if yr_list[i][:11] == 'INMET_CO_GO':
            cities_go[f'{yr}_{j}'] = (yr_list[i][17:-28])
            j+=1
        if yr_list[i][:11] == 'INMET_NE_BA':
            cities_ba[f'{yr}_{j}'] = (yr_list[i][17:-28])
            j+=1
        i+=1
display(cities_mg, cities_sp)
# Out:
# {'2003_12': 'BARBACENA',
#  '2003_13': 'ARAXA',
#  '2003_14': 'MONTES CLAROS',
#  '2003_15': 'UBERLANDIA',
#  '2003_16': 'ALMENARA',
#  '2004_12': 'BARBACENA',
#  '2004_13': 'ARAXA',
#  '2004_14': 'MONTES CLAROS',
#  '2004_15': 'UBERLANDIA',
#  '2004_16': 'ALMENARA',
#  '2004_17': 'MONTE VERDE',
#  '2005_12': 'BARBACENA',
#  '2005_13': 'ARAXA',
#  '2005_14': 'MONTES CLAROS',
#  '2005_15': 'UBERLANDIA',
#  '2005_16': 'ALMENARA',
#  '2005_17': 'MONTE VERDE',
#  '2005_18': 'VICOSA',
#  '2006_14': 'BARBACENA',
#  '2006_15': 'ARAXA',
#  '2006_16': 'MONTES CLAROS',
#  '2006_17': 'UBERLANDIA',
#  '2006_18': 'ALMENARA',
#  '2006_19': 'MONTE VERDE',
#  '2006_20': 'VICOSA',
#  '2006_21': 'TIMOTEO',
#  '2006_22': 'ITUIUTABA',
#  '2006_23': 'OURO BRANCO',
#  '2006_24': 'SAO JOAO DEL REI',
#  '2006_25': 'VARGINHA',
#  '2006_26': 'PASSOS',
#  '2006_27': 'MURIAE',
#  '2006_28': 'CAMPINA VERDE',
#  '2006_29': 'CONCEICAO DAS ALAGOAS',
#  '2006_30': 'PAMPULHA',
#  '2006_31': 'SERRA DOS AIMORES',
#  '2006_32': 'PATROCINIO',
#  '2006_33': 'FORMIGA',
#  '2006_34': 'SACRAMENTO',
#  '2006_35': 'TEOFILO OTONI',
#  '2006_36': 'TRES MARIAS',
#  '2006_37': 'CALDAS',
#  '2006_38': 'MARIA DA FE',
#  '2006_39': 'CURVELO',
#  '2007_33': 'BARBACENA',
#  '2007_34': 'ARAXA',
#  '2007_35': 'MONTES CLAROS',
#  '2007_36': 'UBERLANDIA',
#  '2007_37': 'ALMENARA',
#  '2007_38': 'MONTE VERDE',
#  '2007_39': 'VICOSA',
#  '2007_40': 'TIMOTEO',
#  '2007_41': 'ITUIUTABA',
#  '2007_42': 'OURO BRANCO',
#  '2007_43': 'SAO JOAO DEL REI',
#  '2007_44': 'VARGINHA',
#  '2007_45': 'PASSOS',
#  '2007_46': 'MURIAE',
#  '2007_47': 'JUIZ DE FORA',
#  '2007_48': 'CAMPINA VERDE',
#  '2007_49': 'CONCEICAO DAS ALAGOAS',
#  '2007_50': 'PAMPULHA',
#  '2007_51': 'SERRA DOS AIMORES',
#  '2007_52': 'PATROCINIO',
#  '2007_53': 'FORMIGA',
#  '2007_54': 'SACRAMENTO',
#  '2007_55': 'MONTALVANIA',
#  '2007_56': 'TEOFILO OTONI',
#  '2007_57': 'TRES MARIAS',
#  '2007_58': 'PASSA QUATRO',
#  '2007_59': 'CALDAS',
#  '2007_60': 'MARIA DA FE',
#  '2007_61': 'GOVERNADOR VALADARES',
#  '2007_62': 'GUANHAES',
#  '2007_63': 'AIMORES',
#  '2007_64': 'DORES DO INDAIA',
#  '2007_65': 'DIAMANTINA',
#  '2007_66': 'CURVELO',
#  '2007_67': 'MOCAMBINHO',
#  '2007_68': 'MANTENA',
#  '2007_69': 'CAPELINHA',
#  '2007_70': 'UNAI',
#  '2007_71': 'ESPINOSA',
#  '2007_72': 'BURITIS',
#  '2007_73': 'PIRAPORA',
#  '2007_74': 'GUARDA-MOR',
#  '2007_75': 'SAO ROMAO',
#  '2007_76': 'CHAPADA GAUCHA',
#  '2007_77': 'AGUAS VERMELHAS',
#  '2007_78': 'ITAOBIM',
#  '2007_79': 'RIO PARDO DE MINAS',
#  '2007_80': 'SALINAS',
#  '2007_81': 'JOAO PINHEIRO',
#  '2007_82': 'CARATINGA',
#  '2008_58': 'BARBACENA',
#  '2008_59': 'ARAXA',
#  '2008_60': 'MONTES CLAROS',
#  '2008_61': 'UBERLANDIA',
#  '2008_62': 'ALMENARA',
#  '2008_63': 'MONTE VERDE',
#  '2008_64': 'VICOSA',
#  '2008_65': 'TIMOTEO',
#  '2008_66': 'ITUIUTABA',
#  '2008_67': 'OURO BRANCO',
#  '2008_68': 'SAO JOAO DEL REI',
#  '2008_69': 'VARGINHA',
#  '2008_70': 'PASSOS',
#  '2008_71': 'MURIAE',
#  '2008_72': 'JUIZ DE FORA',
#  '2008_73': 'CAMPINA VERDE',
#  '2008_74': 'CONCEICAO DAS ALAGOAS',
#  '2008_75': 'PAMPULHA',
#  '2008_76': 'SERRA DOS AIMORES',
#  '2008_77': 'PATROCINIO',
#  '2008_78': 'FORMIGA',
#  '2008_79': 'SACRAMENTO',
#  '2008_80': 'MONTALVANIA',
#  '2008_81': 'TEOFILO OTONI',
#  '2008_82': 'TRES MARIAS',
#  '2008_83': 'PASSA QUATRO',
#  '2008_84': 'CALDAS',
#  '2008_85': 'MARIA DA FE',
#  '2008_86': 'GOVERNADOR VALADARES',
#  '2008_87': 'GUANHAES',
#  '2008_88': 'AIMORES',
#  '2008_89': 'FLORESTAL',
#  '2008_90': 'DORES DO INDAIA',
#  '2008_91': 'DIAMANTINA',
#  '2008_92': 'CURVELO',
#  '2008_93': 'MOCAMBINHO',
#  '2008_94': 'MANTENA',
#  '2008_95': 'CAPELINHA',
#  '2008_96': 'UNAI',
#  '2008_97': 'ESPINOSA',
#  '2008_98': 'BURITIS',
#  '2008_99': 'PIRAPORA',
#  '2008_100': 'GUARDA-MOR',
#  '2008_101': 'SAO ROMAO',
#  '2008_102': 'CHAPADA GAUCHA',
#  '2008_103': 'AGUAS VERMELHAS',
#  '2008_104': 'ITAOBIM',
#  '2008_105': 'RIO PARDO DE MINAS',
#  '2008_106': 'SALINAS',
#  '2008_107': 'JOAO PINHEIRO',
#  '2008_108': 'CARATINGA',
#  '2008_109': 'IBIRITE (ROLA MOCA)',
#  '2009_62': 'BARBACENA',
#  '2009_63': 'ARAXA',
#  '2009_64': 'MONTES CLAROS',
#  '2009_65': 'UBERLANDIA',
#  '2009_66': 'ALMENARA',
#  '2009_67': 'MONTE VERDE',
#  '2009_68': 'VICOSA',
#  '2009_69': 'TIMOTEO',
#  '2009_70': 'ITUIUTABA',
#  '2009_71': 'OURO BRANCO',
#  '2009_72': 'SAO JOAO DEL REI',
#  '2009_73': 'VARGINHA',
#  '2009_74': 'PASSOS',
#  '2009_75': 'MURIAE',
#  '2009_76': 'JUIZ DE FORA',
#  '2009_77': 'CAMPINA VERDE',
#  '2009_78': 'CONCEICAO DAS ALAGOAS',
#  '2009_79': 'PAMPULHA',
#  '2009_80': 'SERRA DOS AIMORES',
#  '2009_81': 'PATROCINIO',
#  '2009_82': 'FORMIGA',
#  '2009_83': 'SACRAMENTO',
#  '2009_84': 'MONTALVANIA',
#  '2009_85': 'TEOFILO OTONI',
#  '2009_86': 'TRES MARIAS',
#  '2009_87': 'PASSA QUATRO',
#  '2009_88': 'CALDAS',
#  '2009_89': 'MARIA DA FE',
#  '2009_90': 'GOVERNADOR VALADARES',
#  '2009_91': 'GUANHAES',
#  '2009_92': 'AIMORES',
#  '2009_93': 'FLORESTAL',
#  '2009_94': 'DORES DO INDAIA',
#  '2009_95': 'DIAMANTINA',
#  '2009_96': 'CURVELO',
#  '2009_97': 'MOCAMBINHO',
#  '2009_98': 'MANTENA',
#  '2009_99': 'CAPELINHA',
#  '2009_100': 'UNAI',
#  '2009_101': 'ESPINOSA',
#  '2009_102': 'BURITIS',
#  '2009_103': 'PIRAPORA',
#  '2009_104': 'GUARDA-MOR',
#  '2009_105': 'SAO ROMAO',
#  '2009_106': 'CHAPADA GAUCHA',
#  '2009_107': 'AGUAS VERMELHAS',
#  '2009_108': 'ITAOBIM',
#  '2009_109': 'RIO PARDO DE MINAS',
#  '2009_110': 'SALINAS',
#  '2009_111': 'JOAO PINHEIRO',
#  '2009_112': 'CARATINGA',
#  '2009_113': 'IBIRITE (ROLA MOCA)',
#  '2010_63': 'BARBACENA',
#  '2010_64': 'ARAXA',
#  '2010_65': 'MONTES CLAROS',
#  '2010_66': 'UBERLANDIA',
#  '2010_67': 'ALMENARA',
#  '2010_68': 'MONTE VERDE',
#  '2010_69': 'VICOSA',
#  '2010_70': 'TIMOTEO',
#  '2010_71': 'ITUIUTABA',
#  '2010_72': 'OURO BRANCO',
#  '2010_73': 'SAO JOAO DEL REI',
#  '2010_74': 'VARGINHA',
#  '2010_75': 'PASSOS',
#  '2010_76': 'MURIAE',
#  '2010_77': 'JUIZ DE FORA',
#  '2010_78': 'CAMPINA VERDE',
#  '2010_79': 'CONCEICAO DAS ALAGOAS',
#  '2010_80': 'PAMPULHA',
#  '2010_81': 'SERRA DOS AIMORES',
#  '2010_82': 'PATROCINIO',
#  '2010_83': 'FORMIGA',
#  '2010_84': 'SACRAMENTO',
#  '2010_85': 'MONTALVANIA',
#  '2010_86': 'TEOFILO OTONI',
#  '2010_87': 'TRES MARIAS',
#  '2010_88': 'PASSA QUATRO',
#  '2010_89': 'CALDAS',
#  '2010_90': 'MARIA DA FE',
#  '2010_91': 'GOVERNADOR VALADARES',
#  '2010_92': 'GUANHAES',
#  '2010_93': 'AIMORES',
#  '2010_94': 'FLORESTAL',
#  '2010_95': 'DORES DO INDAIA',
#  '2010_96': 'DIAMANTINA',
#  '2010_97': 'CURVELO',
#  '2010_98': 'MOCAMBINHO',
#  '2010_99': 'MANTENA',
#  '2010_100': 'CAPELINHA',
#  '2010_101': 'UNAI',
#  '2010_102': 'ESPINOSA',
#  '2010_103': 'BURITIS',
#  '2010_104': 'PIRAPORA',
#  '2010_105': 'GUARDA-MOR',
#  '2010_106': 'SAO ROMAO',
#  '2010_107': 'CHAPADA GAUCHA',
#  '2010_108': 'AGUAS VERMELHAS',
#  '2010_109': 'ITAOBIM',
#  '2010_110': 'RIO PARDO DE MINAS',
#  '2010_111': 'SALINAS',
#  '2010_112': 'JOAO PINHEIRO',
#  '2010_113': 'CARATINGA',
#  '2010_114': 'IBIRITE (ROLA MOCA)',
#  '2010_115': 'MANHUACU',
#  '2011_63': 'BARBACENA',
#  '2011_64': 'ARAXA',
#  '2011_65': 'MONTES CLAROS',
#  '2011_66': 'UBERLANDIA',
#  '2011_67': 'ALMENARA',
#  '2011_68': 'MONTE VERDE',
#  '2011_69': 'VICOSA',
#  '2011_70': 'TIMOTEO',
#  '2011_71': 'ITUIUTABA',
#  '2011_72': 'OURO BRANCO',
#  '2011_73': 'SAO JOAO DEL REI',
#  '2011_74': 'VARGINHA',
#  '2011_75': 'PASSOS',
#  '2011_76': 'MURIAE',
#  '2011_77': 'JUIZ DE FORA',
#  '2011_78': 'CAMPINA VERDE',
#  '2011_79': 'CONCEICAO DAS ALAGOAS',
#  '2011_80': 'PAMPULHA',
#  '2011_81': 'SERRA DOS AIMORES',
#  '2011_82': 'PATROCINIO',
#  '2011_83': 'FORMIGA',
#  '2011_84': 'SACRAMENTO',
#  '2011_85': 'MONTALVANIA',
#  '2011_86': 'TEOFILO OTONI',
#  '2011_87': 'TRES MARIAS',
#  '2011_88': 'PASSA QUATRO',
#  '2011_89': 'CALDAS',
#  '2011_90': 'MARIA DA FE',
#  '2011_91': 'GOVERNADOR VALADARES',
#  '2011_92': 'GUANHAES',
#  '2011_93': 'AIMORES',
#  '2011_94': 'FLORESTAL',
#  '2011_95': 'DORES DO INDAIA',
#  '2011_96': 'DIAMANTINA',
#  '2011_97': 'CURVELO',
#  '2011_98': 'MOCAMBINHO',
#  '2011_99': 'MANTENA',
#  '2011_100': 'CAPELINHA',
#  '2011_101': 'UNAI',
#  '2011_102': 'ESPINOSA',
#  '2011_103': 'BURITIS',
#  '2011_104': 'PIRAPORA',
#  '2011_105': 'GUARDA-MOR',
#  '2011_106': 'SAO ROMAO',
#  '2011_107': 'CHAPADA GAUCHA',
#  '2011_108': 'AGUAS VERMELHAS',
#  '2011_109': 'ITAOBIM',
#  '2011_110': 'RIO PARDO DE MINAS',
#  '2011_111': 'SALINAS',
#  '2011_112': 'JOAO PINHEIRO',
#  '2011_113': 'CARATINGA',
#  '2011_114': 'IBIRITE (ROLA MOCA)',
#  '2011_115': 'MANHUACU',
#  '2012_63': 'BARBACENA',
#  '2012_64': 'ARAXA',
#  '2012_65': 'MONTES CLAROS',
#  '2012_66': 'UBERLANDIA',
#  '2012_67': 'ALMENARA',
#  '2012_68': 'MONTE VERDE',
#  '2012_69': 'VICOSA',
#  '2012_70': 'TIMOTEO',
#  '2012_71': 'ITUIUTABA',
#  '2012_72': 'OURO BRANCO',
#  '2012_73': 'SAO JOAO DEL REI',
#  '2012_74': 'VARGINHA',
#  '2012_75': 'PASSOS',
#  '2012_76': 'MURIAE',
#  '2012_77': 'JUIZ DE FORA',
#  '2012_78': 'CAMPINA VERDE',
#  '2012_79': 'CONCEICAO DAS ALAGOAS',
#  '2012_80': 'PAMPULHA',
#  '2012_81': 'SERRA DOS AIMORES',
#  '2012_82': 'PATROCINIO',
#  '2012_83': 'FORMIGA',
#  '2012_84': 'SACRAMENTO',
#  '2012_85': 'MONTALVANIA',
#  '2012_86': 'TEOFILO OTONI',
#  '2012_87': 'TRES MARIAS',
#  '2012_88': 'PASSA QUATRO',
#  '2012_89': 'CALDAS',
#  '2012_90': 'MARIA DA FE',
#  '2012_91': 'GOVERNADOR VALADARES',
#  '2012_92': 'GUANHAES',
#  '2012_93': 'AIMORES',
#  '2012_94': 'FLORESTAL',
#  '2012_95': 'DORES DO INDAIA',
#  '2012_96': 'DIAMANTINA',
#  '2012_97': 'CURVELO',
#  '2012_98': 'MOCAMBINHO',
#  '2012_99': 'MANTENA',
#  '2012_100': 'CAPELINHA',
#  '2012_101': 'UNAI',
#  '2012_102': 'ESPINOSA',
#  '2012_103': 'BURITIS',
#  '2012_104': 'PIRAPORA',
#  '2012_105': 'GUARDA-MOR',
#  '2012_106': 'SAO ROMAO',
#  '2012_107': 'CHAPADA GAUCHA',
#  '2012_108': 'AGUAS VERMELHAS',
#  '2012_109': 'ITAOBIM',
#  '2012_110': 'RIO PARDO DE MINAS',
#  '2012_111': 'SALINAS',
#  '2012_112': 'JOAO PINHEIRO',
#  '2012_113': 'CARATINGA',
#  '2012_114': 'IBIRITE (ROLA MOCA)',
#  '2012_115': 'MANHUACU',
#  '2012_116': 'CORONEL PACHECO',
#  '2013_64': 'BARBACENA',
#  '2013_65': 'ARAXA',
#  '2013_66': 'MONTES CLAROS',
#  '2013_67': 'UBERLANDIA',
#  '2013_68': 'ALMENARA',
#  '2013_69': 'MONTE VERDE',
#  '2013_70': 'VICOSA',
#  '2013_71': 'TIMOTEO',
#  '2013_72': 'ITUIUTABA',
#  '2013_73': 'OURO BRANCO',
#  '2013_74': 'SAO JOAO DEL REI',
#  '2013_75': 'VARGINHA',
#  '2013_76': 'PASSOS',
#  '2013_77': 'MURIAE',
#  '2013_78': 'JUIZ DE FORA',
#  '2013_79': 'CAMPINA VERDE',
#  '2013_80': 'CONCEICAO DAS ALAGOAS',
#  '2013_81': 'PAMPULHA',
#  '2013_82': 'SERRA DOS AIMORES',
#  '2013_83': 'PATROCINIO',
#  '2013_84': 'FORMIGA',
#  '2013_85': 'SACRAMENTO',
#  '2013_86': 'MONTALVANIA',
#  '2013_87': 'TEOFILO OTONI',
#  '2013_88': 'TRES MARIAS',
#  '2013_89': 'PASSA QUATRO',
#  '2013_90': 'CALDAS',
#  '2013_91': 'MARIA DA FE',
#  '2013_92': 'GOVERNADOR VALADARES',
#  '2013_93': 'GUANHAES',
#  '2013_94': 'AIMORES',
#  '2013_95': 'FLORESTAL',
#  '2013_96': 'DORES DO INDAIA',
#  '2013_97': 'DIAMANTINA',
#  '2013_98': 'CURVELO',
#  '2013_99': 'MOCAMBINHO',
#  '2013_100': 'MANTENA',
#  '2013_101': 'CAPELINHA',
#  '2013_102': 'UNAI',
#  '2013_103': 'ESPINOSA',
#  '2013_104': 'BURITIS',
#  '2013_105': 'PIRAPORA',
#  '2013_106': 'GUARDA-MOR',
#  '2013_107': 'SAO ROMAO',
#  '2013_108': 'CHAPADA GAUCHA',
#  '2013_109': 'AGUAS VERMELHAS',
#  '2013_110': 'ITAOBIM',
#  '2013_111': 'RIO PARDO DE MINAS',
#  '2013_112': 'SALINAS',
#  '2013_113': 'JOAO PINHEIRO',
#  '2013_114': 'CARATINGA',
#  '2013_115': 'IBIRITE (ROLA MOCA)',
#  '2013_116': 'MANHUACU',
#  '2013_117': 'CORONEL PACHECO',
#  '2013_118': 'BELO HORIZONTE - CERCADINHO',
#  '2014_65': 'BARBACENA',
#  '2014_66': 'ARAXA',
#  '2014_67': 'MONTES CLAROS',
#  '2014_68': 'UBERLANDIA',
#  '2014_69': 'ALMENARA',
#  '2014_70': 'MONTE VERDE',
#  '2014_71': 'VICOSA',
#  '2014_72': 'TIMOTEO',
#  '2014_73': 'ITUIUTABA',
#  '2014_74': 'OURO BRANCO',
#  '2014_75': 'SAO JOAO DEL REI',
#  '2014_76': 'VARGINHA',
#  '2014_77': 'PASSOS',
#  '2014_78': 'MURIAE',
#  '2014_79': 'JUIZ DE FORA',
#  '2014_80': 'CAMPINA VERDE',
#  '2014_81': 'CONCEICAO DAS ALAGOAS',
#  '2014_82': 'PAMPULHA',
#  '2014_83': 'SERRA DOS AIMORES',
#  '2014_84': 'PATROCINIO',
#  '2014_85': 'FORMIGA',
#  '2014_86': 'SACRAMENTO',
#  '2014_87': 'MONTALVANIA',
#  '2014_88': 'TEOFILO OTONI',
#  '2014_89': 'TRES MARIAS',
#  '2014_90': 'PASSA QUATRO',
#  '2014_91': 'CALDAS',
#  '2014_92': 'MARIA DA FE',
#  '2014_93': 'GOVERNADOR VALADARES',
#  '2014_94': 'GUANHAES',
#  '2014_95': 'AIMORES',
#  '2014_96': 'FLORESTAL',
#  '2014_97': 'DORES DO INDAIA',
#  '2014_98': 'DIAMANTINA',
#  '2014_99': 'CURVELO',
#  '2014_100': 'MOCAMBINHO',
#  '2014_101': 'MANTENA',
#  '2014_102': 'CAPELINHA',
#  '2014_103': 'UNAI',
#  '2014_104': 'ESPINOSA',
#  '2014_105': 'BURITIS',
#  '2014_106': 'PIRAPORA',
#  '2014_107': 'GUARDA-MOR',
#  '2014_108': 'SAO ROMAO',
#  '2014_109': 'CHAPADA GAUCHA',
#  '2014_110': 'AGUAS VERMELHAS',
#  '2014_111': 'ITAOBIM',
#  '2014_112': 'RIO PARDO DE MINAS',
#  '2014_113': 'SALINAS',
#  '2014_114': 'JOAO PINHEIRO',
#  '2014_115': 'CARATINGA',
#  '2014_116': 'IBIRITE (ROLA MOCA)',
#  '2014_117': 'MANHUACU',
#  '2014_118': 'CORONEL PACHECO',
#  '2014_119': 'BELO HORIZONTE - CERCADINHO',
#  '2015_67': 'BARBACENA',
#  '2015_68': 'ARAXA',
#  '2015_69': 'MONTES CLAROS',
#  '2015_70': 'UBERLANDIA',
#  '2015_71': 'ALMENARA',
#  '2015_72': 'MONTE VERDE',
#  '2015_73': 'VICOSA',
#  '2015_74': 'TIMOTEO',
#  '2015_75': 'ITUIUTABA',
#  '2015_76': 'OURO BRANCO',
#  '2015_77': 'SAO JOAO DEL REI',
#  '2015_78': 'VARGINHA',
#  '2015_79': 'PASSOS',
#  '2015_80': 'MURIAE',
#  '2015_81': 'JUIZ DE FORA',
#  '2015_82': 'CAMPINA VERDE',
#  '2015_83': 'CONCEICAO DAS ALAGOAS',
#  '2015_84': 'PAMPULHA',
#  '2015_85': 'SERRA DOS AIMORES',
#  '2015_86': 'PATROCINIO',
#  '2015_87': 'FORMIGA',
#  '2015_88': 'SACRAMENTO',
#  '2015_89': 'MONTALVANIA',
#  '2015_90': 'TEOFILO OTONI',
#  '2015_91': 'TRES MARIAS',
#  '2015_92': 'PASSA QUATRO',
#  '2015_93': 'CALDAS',
#  '2015_94': 'MARIA DA FE',
#  '2015_95': 'GOVERNADOR VALADARES',
#  '2015_96': 'GUANHAES',
#  '2015_97': 'AIMORES',
#  '2015_98': 'FLORESTAL',
#  '2015_99': 'DORES DO INDAIA',
#  '2015_100': 'DIAMANTINA',
#  '2015_101': 'CURVELO',
#  '2015_102': 'MOCAMBINHO',
#  '2015_103': 'MANTENA',
#  '2015_104': 'CAPELINHA',
#  '2015_105': 'UNAI',
#  '2015_106': 'ESPINOSA',
#  '2015_107': 'BURITIS',
#  '2015_108': 'PIRAPORA',
#  '2015_109': 'GUARDA-MOR',
#  '2015_110': 'SAO ROMAO',
#  '2015_111': 'CHAPADA GAUCHA',
#  '2015_112': 'AGUAS VERMELHAS',
#  '2015_113': 'ITAOBIM',
#  '2015_114': 'RIO PARDO DE MINAS',
#  '2015_115': 'SALINAS',
#  '2015_116': 'JOAO PINHEIRO',
#  '2015_117': 'CARATINGA',
#  '2015_118': 'IBIRITE (ROLA MOCA)',
#  '2015_119': 'MANHUACU',
#  '2015_120': 'CORONEL PACHECO',
#  '2015_121': 'SAO SEBASTIAO DO PARAISO',
#  '2015_122': 'BELO HORIZONTE - CERCADINHO',
#  '2016_71': 'BARBACENA',
#  '2016_72': 'ARAXA',
#  '2016_73': 'MONTES CLAROS',
#  '2016_74': 'UBERLANDIA',
#  '2016_75': 'ALMENARA',
#  '2016_76': 'MONTE VERDE',
#  '2016_77': 'VICOSA',
#  '2016_78': 'TIMOTEO',
#  '2016_79': 'ITUIUTABA',
#  '2016_80': 'OURO BRANCO',
#  '2016_81': 'SAO JOAO DEL REI',
#  '2016_82': 'VARGINHA',
#  '2016_83': 'PASSOS',
#  '2016_84': 'MURIAE',
#  '2016_85': 'JUIZ DE FORA',
#  '2016_86': 'CAMPINA VERDE',
#  '2016_87': 'CONCEICAO DAS ALAGOAS',
#  '2016_88': 'PAMPULHA',
#  '2016_89': 'SERRA DOS AIMORES',
#  '2016_90': 'PATROCINIO',
#  '2016_91': 'FORMIGA',
#  '2016_92': 'SACRAMENTO',
#  '2016_93': 'MONTALVANIA',
#  '2016_94': 'TEOFILO OTONI',
#  '2016_95': 'TRES MARIAS',
#  '2016_96': 'PASSA QUATRO',
#  '2016_97': 'CALDAS',
#  '2016_98': 'MARIA DA FE',
#  '2016_99': 'GOVERNADOR VALADARES',
#  '2016_100': 'GUANHAES',
#  '2016_101': 'AIMORES',
#  '2016_102': 'FLORESTAL',
#  '2016_103': 'DORES DO INDAIA',
#  '2016_104': 'DIAMANTINA',
#  '2016_105': 'CURVELO',
#  '2016_106': 'MOCAMBINHO',
#  '2016_107': 'MANTENA',
#  '2016_108': 'CAPELINHA',
#  '2016_109': 'UNAI',
#  '2016_110': 'ESPINOSA',
#  '2016_111': 'BURITIS',
#  '2016_112': 'PIRAPORA',
#  '2016_113': 'GUARDA-MOR',
#  '2016_114': 'SAO ROMAO',
#  '2016_115': 'CHAPADA GAUCHA',
#  '2016_116': 'AGUAS VERMELHAS',
#  '2016_117': 'ITAOBIM',
#  '2016_118': 'RIO PARDO DE MINAS',
#  '2016_119': 'SALINAS',
#  '2016_120': 'JOAO PINHEIRO',
#  '2016_121': 'CARATINGA',
#  '2016_122': 'IBIRITE (ROLA MOCA)',
#  '2016_123': 'MANHUACU',
#  '2016_124': 'CORONEL PACHECO',
#  '2016_125': 'JANUARIA',
#  '2016_126': 'SAO SEBASTIAO DO PARAISO',
#  '2016_127': 'JANAUBA',
#  '2016_128': 'BAMBUI',
#  '2016_129': 'SETE LAGOAS',
#  '2016_130': 'BELO HORIZONTE - CERCADINHO',
#  '2016_131': 'EB_PEF_BONFIM',
#  '2017_75': 'BARBACENA',
#  '2017_76': 'ARAXA',
#  '2017_77': 'MONTES CLAROS',
#  '2017_78': 'UBERLANDIA',
#  '2017_79': 'ALMENARA',
#  '2017_80': 'MONTE VERDE',
#  '2017_81': 'VICOSA',
#  '2017_82': 'TIMOTEO',
#  '2017_83': 'ITUIUTABA',
#  '2017_84': 'OURO BRANCO',
#  '2017_85': 'SAO JOAO DEL REI',
#  '2017_86': 'VARGINHA',
#  '2017_87': 'PASSOS',
#  '2017_88': 'MURIAE',
#  '2017_89': 'JUIZ DE FORA',
#  '2017_90': 'CAMPINA VERDE',
#  '2017_91': 'CONCEICAO DAS ALAGOAS',
#  '2017_92': 'PAMPULHA',
#  '2017_93': 'SERRA DOS AIMORES',
#  '2017_94': 'PATROCINIO',
#  '2017_95': 'FORMIGA',
#  '2017_96': 'SACRAMENTO',
#  '2017_97': 'MONTALVANIA',
#  '2017_98': 'TEOFILO OTONI',
#  '2017_99': 'TRES MARIAS',
#  '2017_100': 'PASSA QUATRO',
#  '2017_101': 'CALDAS',
#  '2017_102': 'MARIA DA FE',
#  '2017_103': 'GOVERNADOR VALADARES',
#  '2017_104': 'GUANHAES',
#  '2017_105': 'AIMORES',
#  '2017_106': 'FLORESTAL',
#  '2017_107': 'DORES DO INDAIA',
#  '2017_108': 'DIAMANTINA',
#  '2017_109': 'CURVELO',
#  '2017_110': 'MOCAMBINHO',
#  '2017_111': 'MANTENA',
#  '2017_112': 'CAPELINHA',
#  '2017_113': 'UNAI',
#  '2017_114': 'ESPINOSA',
#  '2017_115': 'BURITIS',
#  '2017_116': 'PIRAPORA',
#  '2017_117': 'GUARDA-MOR',
#  '2017_118': 'SAO ROMAO',
#  '2017_119': 'CHAPADA GAUCHA',
#  '2017_120': 'AGUAS VERMELHAS',
#  '2017_121': 'ITAOBIM',
#  '2017_122': 'RIO PARDO DE MINAS',
#  '2017_123': 'SALINAS',
#  '2017_124': 'JOAO PINHEIRO',
#  '2017_125': 'CARATINGA',
#  '2017_126': 'IBIRITE (ROLA MOCA)',
#  '2017_127': 'MANHUACU',
#  '2017_128': 'CORONEL PACHECO',
#  '2017_129': 'JANUARIA',
#  '2017_130': 'SAO SEBASTIAO DO PARAISO',
#  '2017_131': 'PATOS DE MINAS',
#  '2017_132': 'JANAUBA',
#  '2017_133': 'DIVINOPOLIS',
#  '2017_134': 'BAMBUI',
#  '2017_135': 'ARACUAI',
#  '2017_136': 'MACHADO',
#  '2017_137': 'UBERABA',
#  '2017_138': 'SETE LAGOAS',
#  '2017_139': 'OLIVEIRA',
#  '2017_140': 'BELO HORIZONTE - CERCADINHO',
#  '2017_141': 'EB_PEF_BONFIM',
#  '2018_79': 'BARBACENA',
#  '2018_80': 'ARAXA',
#  '2018_81': 'MONTES CLAROS',
#  '2018_82': 'UBERLANDIA',
#  '2018_83': 'ALMENARA',
#  '2018_84': 'MONTE VERDE',
#  '2018_85': 'VICOSA',
#  '2018_86': 'TIMOTEO',
#  '2018_87': 'ITUIUTABA',
#  '2018_88': 'OURO BRANCO',
#  '2018_89': 'SAO JOAO DEL REI',
#  '2018_90': 'VARGINHA',
#  '2018_91': 'PASSOS',
#  '2018_92': 'MURIAE',
#  '2018_93': 'JUIZ DE FORA',
#  '2018_94': 'CAMPINA VERDE',
#  '2018_95': 'CONCEICAO DAS ALAGOAS',
#  '2018_96': 'PAMPULHA',
#  '2018_97': 'SERRA DOS AIMORES',
#  '2018_98': 'PATROCINIO',
#  '2018_99': 'FORMIGA',
#  '2018_100': 'SACRAMENTO',
#  '2018_101': 'MONTALVANIA',
#  '2018_102': 'TEOFILO OTONI',
#  '2018_103': 'TRES MARIAS',
#  '2018_104': 'PASSA QUATRO',
#  '2018_105': 'CALDAS',
#  '2018_106': 'MARIA DA FE',
#  '2018_107': 'GOVERNADOR VALADARES',
#  '2018_108': 'GUANHAES',
#  '2018_109': 'AIMORES',
#  '2018_110': 'FLORESTAL',
#  '2018_111': 'DORES DO INDAIA',
#  '2018_112': 'DIAMANTINA',
#  '2018_113': 'CURVELO',
#  '2018_114': 'MOCAMBINHO',
#  '2018_115': 'MANTENA',
#  '2018_116': 'CAPELINHA',
#  '2018_117': 'UNAI',
#  '2018_118': 'ESPINOSA',
#  '2018_119': 'BURITIS',
#  '2018_120': 'PIRAPORA',
#  '2018_121': 'GUARDA-MOR',
#  '2018_122': 'SAO ROMAO',
#  '2018_123': 'CHAPADA GAUCHA',
#  '2018_124': 'AGUAS VERMELHAS',
#  '2018_125': 'ITAOBIM',
#  '2018_126': 'RIO PARDO DE MINAS',
#  '2018_127': 'SALINAS',
#  '2018_128': 'JOAO PINHEIRO',
#  '2018_129': 'CARATINGA',
#  '2018_130': 'IBIRITE (ROLA MOCA)',
#  '2018_131': 'MANHUACU',
#  '2018_132': 'CORONEL PACHECO',
#  '2018_133': 'JANUARIA',
#  '2018_134': 'SAO SEBASTIAO DO PARAISO',
#  '2018_135': 'PATOS DE MINAS',
#  '2018_136': 'JANAUBA',
#  '2018_137': 'DIVINOPOLIS',
#  '2018_138': 'BAMBUI',
#  '2018_139': 'ARACUAI',
#  '2018_140': 'MACHADO',
#  '2018_141': 'UBERABA',
#  '2018_142': 'SETE LAGOAS',
#  '2018_143': 'OLIVEIRA',
#  '2018_144': 'PARACATU',
#  '2018_145': 'BELO HORIZONTE - CERCADINHO',
#  '2018_146': 'EB_PEF_BONFIM',
#  '2019_78': 'BARBACENA',
#  '2019_79': 'ARAXA',
#  '2019_80': 'MONTES CLAROS',
#  '2019_81': 'UBERLANDIA',
#  '2019_82': 'ALMENARA',
#  '2019_83': 'MONTE VERDE',
#  '2019_84': 'VICOSA',
#  '2019_85': 'TIMOTEO',
#  '2019_86': 'ITUIUTABA',
#  '2019_87': 'OURO BRANCO',
#  '2019_88': 'SAO JOAO DEL REI',
#  '2019_89': 'VARGINHA',
#  '2019_90': 'PASSOS',
#  '2019_91': 'MURIAE',
#  '2019_92': 'JUIZ DE FORA',
#  '2019_93': 'CAMPINA VERDE',
#  '2019_94': 'CONCEICAO DAS ALAGOAS',
#  '2019_95': 'PAMPULHA',
#  '2019_96': 'SERRA DOS AIMORES',
#  '2019_97': 'PATROCINIO',
#  '2019_98': 'FORMIGA',
#  '2019_99': 'SACRAMENTO',
#  '2019_100': 'MONTALVANIA',
#  '2019_101': 'TEOFILO OTONI',
#  '2019_102': 'TRES MARIAS',
#  '2019_103': 'PASSA QUATRO',
#  '2019_104': 'CALDAS',
#  '2019_105': 'MARIA DA FE',
#  '2019_106': 'GOVERNADOR VALADARES',
#  '2019_107': 'GUANHAES',
#  '2019_108': 'AIMORES',
#  '2019_109': 'FLORESTAL',
#  '2019_110': 'DORES DO INDAIA',
#  '2019_111': 'DIAMANTINA',
#  '2019_112': 'CURVELO',
#  '2019_113': 'MOCAMBINHO',
#  '2019_114': 'MANTENA',
#  '2019_115': 'CAPELINHA',
#  '2019_116': 'UNAI',
#  '2019_117': 'ESPINOSA',
#  '2019_118': 'BURITIS',
#  '2019_119': 'PIRAPORA',
#  '2019_120': 'GUARDA-MOR',
#  '2019_121': 'SAO ROMAO',
#  '2019_122': 'CHAPADA GAUCHA',
#  '2019_123': 'AGUAS VERMELHAS',
#  '2019_124': 'ITAOBIM',
#  '2019_125': 'RIO PARDO DE MINAS',
#  '2019_126': 'SALINAS',
#  '2019_127': 'JOAO PINHEIRO',
#  '2019_128': 'CARATINGA',
#  '2019_129': 'IBIRITE (ROLA MOCA)',
#  '2019_130': 'MANHUACU',
#  '2019_131': 'CORONEL PACHECO',
#  '2019_132': 'JANUARIA',
#  '2019_133': 'SAO SEBASTIAO DO PARAISO',
#  '2019_134': 'PATOS DE MINAS',
#  '2019_135': 'JANAUBA',
#  '2019_136': 'DIVINOPOLIS',
#  '2019_137': 'BAMBUI',
#  '2019_138': 'ARACUAI',
#  '2019_139': 'MACHADO',
#  '2019_140': 'UBERABA',
#  '2019_141': 'SETE LAGOAS',
#  '2019_142': 'OLIVEIRA',
#  '2019_143': 'PARACATU',
#  '2019_144': 'BELO HORIZONTE - CERCADINHO',
#  '2020_78': 'BARBACENA',
#  '2020_79': 'ARAXA',
#  '2020_80': 'MONTES CLAROS',
#  '2020_81': 'UBERLANDIA',
#  '2020_82': 'ALMENARA',
#  '2020_83': 'MONTE VERDE',
#  '2020_84': 'VICOSA',
#  '2020_85': 'TIMOTEO',
#  '2020_86': 'ITUIUTABA',
#  '2020_87': 'OURO BRANCO',
#  '2020_88': 'SAO JOAO DEL REI',
#  '2020_89': 'VARGINHA',
#  '2020_90': 'PASSOS',
#  '2020_91': 'MURIAE',
#  '2020_92': 'JUIZ DE FORA',
#  '2020_93': 'CAMPINA VERDE',
#  '2020_94': 'CONCEICAO DAS ALAGOAS',
#  '2020_95': 'PAMPULHA',
#  '2020_96': 'SERRA DOS AIMORES',
#  '2020_97': 'PATROCINIO',
#  '2020_98': 'FORMIGA',
#  '2020_99': 'SACRAMENTO',
#  '2020_100': 'MONTALVANIA',
#  '2020_101': 'TEOFILO OTONI',
#  '2020_102': 'TRES MARIAS',
#  '2020_103': 'PASSA QUATRO',
#  '2020_104': 'CALDAS',
#  '2020_105': 'MARIA DA FE',
#  '2020_106': 'GOVERNADOR VALADARES',
#  '2020_107': 'GUANHAES',
#  '2020_108': 'AIMORES',
#  '2020_109': 'FLORESTAL',
#  '2020_110': 'DORES DO INDAIA',
#  '2020_111': 'DIAMANTINA',
#  '2020_112': 'CURVELO',
#  '2020_113': 'MOCAMBINHO',
#  '2020_114': 'MANTENA',
#  '2020_115': 'CAPELINHA',
#  '2020_116': 'UNAI',
#  '2020_117': 'ESPINOSA',
#  '2020_118': 'BURITIS',
#  '2020_119': 'PIRAPORA',
#  '2020_120': 'GUARDA-MOR',
#  '2020_121': 'SAO ROMAO',
#  '2020_122': 'CHAPADA GAUCHA',
#  '2020_123': 'AGUAS VERMELHAS',
#  '2020_124': 'ITAOBIM',
#  '2020_125': 'RIO PARDO DE MINAS',
#  '2020_126': 'SALINAS',
#  '2020_127': 'JOAO PINHEIRO',
#  '2020_128': 'CARATINGA',
#  '2020_129': 'IBIRITE (ROLA MOCA)',
#  '2020_130': 'MANHUACU',
#  '2020_131': 'CORONEL PACHECO',
#  '2020_132': 'JANUARIA',
#  '2020_133': 'SAO SEBASTIAO DO PARAISO',
#  '2020_134': 'PATOS DE MINAS',
#  '2020_135': 'JANAUBA',
#  '2020_136': 'DIVINOPOLIS',
#  '2020_137': 'BAMBUI',
#  '2020_138': 'ARACUAI',
#  '2020_139': 'MACHADO',
#  '2020_140': 'UBERABA',
#  '2020_141': 'SETE LAGOAS',
#  '2020_142': 'OLIVEIRA',
#  '2020_143': 'PARACATU',
#  '2020_144': 'BELO HORIZONTE - CERCADINHO',
#  '2021_78': 'BARBACENA',
#  '2021_79': 'ARAXA',
#  '2021_80': 'MONTES CLAROS',
#  '2021_81': 'UBERLANDIA',
#  '2021_82': 'ALMENARA',
#  '2021_83': 'MONTE VERDE',
#  '2021_84': 'VICOSA',
#  '2021_85': 'TIMOTEO',
#  '2021_86': 'ITUIUTABA',
#  '2021_87': 'OURO BRANCO',
#  '2021_88': 'SAO JOAO DEL REI',
#  '2021_89': 'VARGINHA',
#  '2021_90': 'PASSOS',
#  '2021_91': 'MURIAE',
#  '2021_92': 'JUIZ DE FORA',
#  '2021_93': 'CAMPINA VERDE',
#  '2021_94': 'CONCEICAO DAS ALAGOAS',
#  '2021_95': 'BELO HORIZONTE (PAMPULHA)',
#  '2021_96': 'SERRA DOS AIMORES',
#  '2021_97': 'PATROCINIO',
#  '2021_98': 'FORMIGA',
#  '2021_99': 'SACRAMENTO',
#  '2021_100': 'MONTALVANIA',
#  '2021_101': 'TEOFILO OTONI',
#  '2021_102': 'TRES MARIAS',
#  '2021_103': 'PASSA QUATRO',
#  '2021_104': 'CALDAS',
#  '2021_105': 'MARIA DA FE',
#  '2021_106': 'GOVERNADOR VALADARES',
#  '2021_107': 'GUANHAES',
#  '2021_108': 'AIMORES',
#  '2021_109': 'FLORESTAL',
#  '2021_110': 'DORES DO INDAIA',
#  '2021_111': 'DIAMANTINA',
#  '2021_112': 'CURVELO',
#  '2021_113': 'MOCAMBINHO',
#  '2021_114': 'MANTENA',
#  '2021_115': 'CAPELINHA',
#  '2021_116': 'UNAI',
#  '2021_117': 'ESPINOSA',
#  '2021_118': 'BURITIS',
#  '2021_119': 'PIRAPORA',
#  '2021_120': 'GUARDA-MOR',
#  '2021_121': 'SAO ROMAO',
#  '2021_122': 'CHAPADA GAUCHA',
#  '2021_123': 'AGUAS VERMELHAS',
#  '2021_124': 'ITAOBIM',
#  '2021_125': 'RIO PARDO DE MINAS',
#  '2021_126': 'SALINAS',
#  '2021_127': 'JOAO PINHEIRO',
#  '2021_128': 'CARATINGA',
#  '2021_129': 'IBIRITE (ROLA MOCA)',
#  '2021_130': 'MANHUACU',
#  '2021_131': 'CORONEL PACHECO',
#  '2021_132': 'JANUARIA',
#  '2021_133': 'POMPEU',
#  '2021_134': 'SAO SEBASTIAO DO PARAISO',
#  '2021_135': 'PATOS DE MINAS',
#  '2021_136': 'JANAUBA',
#  '2021_137': 'DIVINOPOLIS',
#  '2021_138': 'BAMBUI',
#  '2021_139': 'ARACUAI',
#  '2021_140': 'MACHADO',
#  '2021_141': 'UBERABA',
#  '2021_142': 'SETE LAGOAS',
#  '2021_143': 'OLIVEIRA',
#  '2021_144': 'PARACATU',
#  '2021_145': 'BELO HORIZONTE - CERCADINHO',
#  '2022_77': 'BARBACENA',
#  '2022_78': 'ARAXA',
#  '2022_79': 'MONTES CLAROS',
#  '2022_80': 'UBERLANDIA',
#  '2022_81': 'ALMENARA',
#  '2022_82': 'MONTE VERDE',
#  '2022_83': 'VICOSA',
#  '2022_84': 'TIMOTEO',
#  '2022_85': 'ITUIUTABA',
#  '2022_86': 'OURO BRANCO',
#  '2022_87': 'SAO JOAO DEL REI',
#  '2022_88': 'VARGINHA',
#  '2022_89': 'PASSOS',
#  '2022_90': 'MURIAE',
#  '2022_91': 'JUIZ DE FORA',
#  '2022_92': 'CAMPINA VERDE',
#  '2022_93': 'CONCEICAO DAS ALAGOAS',
#  '2022_94': 'BELO HORIZONTE (PAMPULHA)',
#  '2022_95': 'SERRA DOS AIMORES',
#  '2022_96': 'PATROCINIO',
#  '2022_97': 'FORMIGA',
#  '2022_98': 'SACRAMENTO',
#  '2022_99': 'MONTALVANIA',
#  '2022_100': 'TEOFILO OTONI',
#  '2022_101': 'TRES MARIAS',
#  '2022_102': 'PASSA QUATRO',
#  '2022_103': 'CALDAS',
#  '2022_104': 'MARIA DA FE',
#  '2022_105': 'GOVERNADOR VALADARES',
#  '2022_106': 'GUANHAES',
#  '2022_107': 'AIMORES',
#  '2022_108': 'FLORESTAL',
#  '2022_109': 'DORES DO INDAIA',
#  '2022_110': 'DIAMANTINA',
#  '2022_111': 'CURVELO',
#  '2022_112': 'MOCAMBINHO',
#  '2022_113': 'MANTENA',
#  '2022_114': 'CAPELINHA',
#  '2022_115': 'UNAI',
#  '2022_116': 'ESPINOSA',
#  '2022_117': 'BURITIS',
#  '2022_118': 'PIRAPORA',
#  '2022_119': 'GUARDA-MOR',
#  '2022_120': 'SAO ROMAO',
#  '2022_121': 'CHAPADA GAUCHA',
#  '2022_122': 'AGUAS VERMELHAS',
#  '2022_123': 'ITAOBIM',
#  '2022_124': 'RIO PARDO DE MINAS',
#  '2022_125': 'SALINAS',
#  '2022_126': 'JOAO PINHEIRO',
#  '2022_127': 'CARATINGA',
#  '2022_128': 'IBIRITE (ROLA MOCA)',
#  '2022_129': 'MANHUACU',
#  '2022_130': 'CORONEL PACHECO',
#  '2022_131': 'JANUARIA',
#  '2022_132': 'POMPEU',
#  '2022_133': 'SAO SEBASTIAO DO PARAISO',
#  '2022_134': 'PATOS DE MINAS',
#  '2022_135': 'NOVA PORTEIRINHA (JANAUBA)',
#  '2022_136': 'DIVINOPOLIS',
#  '2022_137': 'BAMBUI',
#  '2022_138': 'ARACUAI',
#  '2022_139': 'MACHADO',
#  '2022_140': 'UBERABA',
#  '2022_141': 'SETE LAGOAS',
#  '2022_142': 'OLIVEIRA',
#  '2022_143': 'PARACATU',
#  '2022_144': 'BELO HORIZONTE - CERCADINHO',
#  '2023_75': 'BARBACENA',
#  '2023_76': 'ARAXA',
#  '2023_77': 'MONTES CLAROS',
#  '2023_78': 'UBERLANDIA',
#  '2023_79': 'ALMENARA',
#  '2023_80': 'MONTE VERDE',
#  '2023_81': 'VICOSA',
#  '2023_82': 'TIMOTEO',
#  '2023_83': 'ITUIUTABA',
#  '2023_84': 'OURO BRANCO',
#  ...}
# {'2003_21': 'BAURU',
#  '2003_22': 'CAMPOS DO JORDAO',
#  '2003_23': 'PRESIDENTE PRUDENTE',
#  '2003_24': 'FRANCA',
#  '2004_22': 'BAURU',
#  '2004_23': 'CAMPOS DO JORDAO',
#  '2004_24': 'PRESIDENTE PRUDENTE',
#  '2004_25': 'FRANCA',
#  '2005_23': 'BAURU',
#  '2005_24': 'CAMPOS DO JORDAO',
#  '2005_25': 'PRESIDENTE PRUDENTE',
#  '2005_26': 'FRANCA',
#  '2006_52': 'SAO PAULO - MIRANTE',
#  '2006_53': 'BAURU',
#  '2006_54': 'CAMPOS DO JORDAO',
#  '2006_55': 'PRESIDENTE PRUDENTE',
#  '2006_56': 'FRANCA',
#  '2006_57': 'SAO CARLOS',
#  '2006_58': 'IGUAPE',
#  '2006_59': 'SOROCABA',
#  '2006_60': 'ITAPEVA',
#  '2006_61': 'SAO MIGUEL ARCANJO',
#  '2006_62': 'OURINHOS',
#  '2006_63': 'RANCHARIA',
#  '2006_64': 'AVARE',
#  '2006_65': 'PIRACICABA',
#  '2006_66': 'LINS',
#  '2006_67': 'TAUBATE',
#  '2006_68': 'VOTUPORANGA',
#  '2007_97': 'SAO PAULO - MIRANTE',
#  '2007_98': 'BAURU',
#  '2007_99': 'CAMPOS DO JORDAO',
#  '2007_100': 'PRESIDENTE PRUDENTE',
#  '2007_101': 'FRANCA',
#  '2007_102': 'SAO CARLOS',
#  '2007_103': 'IGUAPE',
#  '2007_104': 'SOROCABA',
#  '2007_105': 'ITAPEVA',
#  '2007_106': 'SAO MIGUEL ARCANJO',
#  '2007_107': 'OURINHOS',
#  '2007_108': 'RANCHARIA',
#  '2007_109': 'AVARE',
#  '2007_110': 'PIRACICABA',
#  '2007_111': 'LINS',
#  '2007_112': 'TAUBATE',
#  '2007_113': 'VOTUPORANGA',
#  '2007_114': 'JALES',
#  '2007_115': 'VALPARAISO',
#  '2007_116': 'JOSE BONIFACIO',
#  '2007_117': 'ARIRANHA',
#  '2007_118': 'IBITINGA',
#  '2007_119': 'CASA BRANCA',
#  '2007_120': 'ITAPIRA',
#  '2007_121': 'SAO LUIS DO PARAITINGA',
#  '2008_125': 'SAO PAULO - MIRANTE',
#  '2008_126': 'BAURU',
#  '2008_127': 'CAMPOS DO JORDAO',
#  '2008_128': 'PRESIDENTE PRUDENTE',
#  '2008_129': 'FRANCA',
#  '2008_130': 'SAO CARLOS',
#  '2008_131': 'IGUAPE',
#  '2008_132': 'SOROCABA',
#  '2008_133': 'ITAPEVA',
#  '2008_134': 'SAO MIGUEL ARCANJO',
#  '2008_135': 'OURINHOS',
#  '2008_136': 'RANCHARIA',
#  '2008_137': 'AVARE',
#  '2008_138': 'PIRACICABA',
#  '2008_139': 'LINS',
#  '2008_140': 'TAUBATE',
#  '2008_141': 'VOTUPORANGA',
#  '2008_142': 'JALES',
#  '2008_143': 'VALPARAISO',
#  '2008_144': 'JOSE BONIFACIO',
#  '2008_145': 'ARIRANHA',
#  '2008_146': 'IBITINGA',
#  '2008_147': 'CASA BRANCA',
#  '2008_148': 'ITAPIRA',
#  '2008_149': 'SAO LUIS DO PARAITINGA',
#  '2008_150': 'BARRA BONITA',
#  '2008_151': 'BARRA DO TURVO',
#  '2008_152': 'PRADOPOLIS',
#  '2008_153': 'ITUVERAVA',
#  '2009_129': 'SAO PAULO - MIRANTE',
#  '2009_130': 'BAURU',
#  '2009_131': 'CAMPOS DO JORDAO',
#  '2009_132': 'PRESIDENTE PRUDENTE',
#  '2009_133': 'FRANCA',
#  '2009_134': 'SAO CARLOS',
#  '2009_135': 'IGUAPE',
#  '2009_136': 'SOROCABA',
#  '2009_137': 'ITAPEVA',
#  '2009_138': 'SAO MIGUEL ARCANJO',
#  '2009_139': 'OURINHOS',
#  '2009_140': 'RANCHARIA',
#  '2009_141': 'AVARE',
#  '2009_142': 'PIRACICABA',
#  '2009_143': 'LINS',
#  '2009_144': 'TAUBATE',
#  '2009_145': 'VOTUPORANGA',
#  '2009_146': 'JALES',
#  '2009_147': 'VALPARAISO',
#  '2009_148': 'JOSE BONIFACIO',
#  '2009_149': 'ARIRANHA',
#  '2009_150': 'IBITINGA',
#  '2009_151': 'CASA BRANCA',
#  '2009_152': 'ITAPIRA',
#  '2009_153': 'SAO LUIS DO PARAITINGA',
#  '2009_154': 'BARRA BONITA',
#  '2009_155': 'BARRA DO TURVO',
#  '2009_156': 'PRADOPOLIS',
#  '2009_157': 'ITUVERAVA',
#  '2010_132': 'SAO PAULO - MIRANTE',
#  '2010_133': 'BAURU',
#  '2010_134': 'CAMPOS DO JORDAO',
#  '2010_135': 'PRESIDENTE PRUDENTE',
#  '2010_136': 'FRANCA',
#  '2010_137': 'SAO CARLOS',
#  '2010_138': 'IGUAPE',
#  '2010_139': 'SOROCABA',
#  '2010_140': 'ITAPEVA',
#  '2010_141': 'SAO MIGUEL ARCANJO',
#  '2010_142': 'OURINHOS',
#  '2010_143': 'RANCHARIA',
#  '2010_144': 'AVARE',
#  '2010_145': 'PIRACICABA',
#  '2010_146': 'LINS',
#  '2010_147': 'TAUBATE',
#  '2010_148': 'VOTUPORANGA',
#  '2010_149': 'JALES',
#  '2010_150': 'VALPARAISO',
#  '2010_151': 'JOSE BONIFACIO',
#  '2010_152': 'ARIRANHA',
#  '2010_153': 'IBITINGA',
#  '2010_154': 'CASA BRANCA',
#  '2010_155': 'ITAPIRA',
#  '2010_156': 'SAO LUIS DO PARAITINGA',
#  '2010_157': 'BARRA BONITA',
#  '2010_158': 'BARRA DO TURVO',
#  '2010_159': 'PRADOPOLIS',
#  '2010_160': 'BARRETOS',
#  '2010_161': 'ITUVERAVA',
#  '2011_132': 'SAO PAULO - MIRANTE',
#  '2011_133': 'BAURU',
#  '2011_134': 'CAMPOS DO JORDAO',
#  '2011_135': 'PRESIDENTE PRUDENTE',
#  '2011_136': 'FRANCA',
#  '2011_137': 'SAO CARLOS',
#  '2011_138': 'IGUAPE',
#  '2011_139': 'SOROCABA',
#  '2011_140': 'ITAPEVA',
#  '2011_141': 'SAO MIGUEL ARCANJO',
#  '2011_142': 'OURINHOS',
#  '2011_143': 'RANCHARIA',
#  '2011_144': 'AVARE',
#  '2011_145': 'PIRACICABA',
#  '2011_146': 'LINS',
#  '2011_147': 'TAUBATE',
#  '2011_148': 'VOTUPORANGA',
#  '2011_149': 'JALES',
#  '2011_150': 'VALPARAISO',
#  '2011_151': 'JOSE BONIFACIO',
#  '2011_152': 'ARIRANHA',
#  '2011_153': 'IBITINGA',
#  '2011_154': 'CASA BRANCA',
#  '2011_155': 'ITAPIRA',
#  '2011_156': 'SAO LUIS DO PARAITINGA',
#  '2011_157': 'BARRA BONITA',
#  '2011_158': 'BARRA DO TURVO',
#  '2011_159': 'PRADOPOLIS',
#  '2011_160': 'BARRETOS',
#  '2011_161': 'ITUVERAVA',
#  '2011_162': 'BARUERI',
#  '2012_133': 'SAO PAULO - MIRANTE',
#  '2012_134': 'BAURU',
#  '2012_135': 'CAMPOS DO JORDAO',
#  '2012_136': 'PRESIDENTE PRUDENTE',
#  '2012_137': 'FRANCA',
#  '2012_138': 'SAO CARLOS',
#  '2012_139': 'IGUAPE',
#  '2012_140': 'SOROCABA',
#  '2012_141': 'ITAPEVA',
#  '2012_142': 'SAO MIGUEL ARCANJO',
#  '2012_143': 'OURINHOS',
#  '2012_144': 'RANCHARIA',
#  '2012_145': 'AVARE',
#  '2012_146': 'PIRACICABA',
#  '2012_147': 'LINS',
#  '2012_148': 'TAUBATE',
#  '2012_149': 'VOTUPORANGA',
#  '2012_150': 'JALES',
#  '2012_151': 'VALPARAISO',
#  '2012_152': 'JOSE BONIFACIO',
#  '2012_153': 'ARIRANHA',
#  '2012_154': 'IBITINGA',
#  '2012_155': 'CASA BRANCA',
#  '2012_156': 'ITAPIRA',
#  '2012_157': 'SAO LUIS DO PARAITINGA',
#  '2012_158': 'BARRA BONITA',
#  '2012_159': 'BARRA DO TURVO',
#  '2012_160': 'PRADOPOLIS',
#  '2012_161': 'BARRETOS',
#  '2012_162': 'ITUVERAVA',
#  '2012_163': 'BARUERI',
#  '2013_135': 'SAO PAULO - MIRANTE',
#  '2013_136': 'BAURU',
#  '2013_137': 'CAMPOS DO JORDAO',
#  '2013_138': 'PRESIDENTE PRUDENTE',
#  '2013_139': 'FRANCA',
#  '2013_140': 'SAO CARLOS',
#  '2013_141': 'IGUAPE',
#  '2013_142': 'SOROCABA',
#  '2013_143': 'ITAPEVA',
#  '2013_144': 'SAO MIGUEL ARCANJO',
#  '2013_145': 'OURINHOS',
#  '2013_146': 'RANCHARIA',
#  '2013_147': 'AVARE',
#  '2013_148': 'PIRACICABA',
#  '2013_149': 'LINS',
#  '2013_150': 'TAUBATE',
#  '2013_151': 'VOTUPORANGA',
#  '2013_152': 'JALES',
#  '2013_153': 'VALPARAISO',
#  '2013_154': 'JOSE BONIFACIO',
#  '2013_155': 'ARIRANHA',
#  '2013_156': 'IBITINGA',
#  '2013_157': 'CASA BRANCA',
#  '2013_158': 'ITAPIRA',
#  '2013_159': 'SAO LUIS DO PARAITINGA',
#  '2013_160': 'BARRA BONITA',
#  '2013_161': 'BARRA DO TURVO',
#  '2013_162': 'PRADOPOLIS',
#  '2013_163': 'BARRETOS',
#  '2013_164': 'ITUVERAVA',
#  '2013_165': 'BARUERI',
#  '2014_136': 'SAO PAULO - MIRANTE',
#  '2014_137': 'BAURU',
#  '2014_138': 'CAMPOS DO JORDAO',
#  '2014_139': 'PRESIDENTE PRUDENTE',
#  '2014_140': 'FRANCA',
#  '2014_141': 'SAO CARLOS',
#  '2014_142': 'IGUAPE',
#  '2014_143': 'SOROCABA',
#  '2014_144': 'ITAPEVA',
#  '2014_145': 'SAO MIGUEL ARCANJO',
#  '2014_146': 'OURINHOS',
#  '2014_147': 'RANCHARIA',
#  '2014_148': 'AVARE',
#  '2014_149': 'PIRACICABA',
#  '2014_150': 'LINS',
#  '2014_151': 'TAUBATE',
#  '2014_152': 'VOTUPORANGA',
#  '2014_153': 'JALES',
#  '2014_154': 'VALPARAISO',
#  '2014_155': 'JOSE BONIFACIO',
#  '2014_156': 'ARIRANHA',
#  '2014_157': 'IBITINGA',
#  '2014_158': 'CASA BRANCA',
#  '2014_159': 'ITAPIRA',
#  '2014_160': 'SAO LUIS DO PARAITINGA',
#  '2014_161': 'BARRA BONITA',
#  '2014_162': 'BARRA DO TURVO',
#  '2014_163': 'PRADOPOLIS',
#  '2014_164': 'BARRETOS',
#  '2014_165': 'ITUVERAVA',
#  '2014_166': 'BARUERI',
#  '2015_141': 'SAO PAULO - MIRANTE',
#  '2015_142': 'BAURU',
#  '2015_143': 'CAMPOS DO JORDAO',
#  '2015_144': 'PRESIDENTE PRUDENTE',
#  '2015_145': 'FRANCA',
#  '2015_146': 'SAO CARLOS',
#  '2015_147': 'IGUAPE',
#  '2015_148': 'SOROCABA',
#  '2015_149': 'ITAPEVA',
#  '2015_150': 'SAO MIGUEL ARCANJO',
#  '2015_151': 'OURINHOS',
#  '2015_152': 'RANCHARIA',
#  '2015_153': 'AVARE',
#  '2015_154': 'PIRACICABA',
#  '2015_155': 'LINS',
#  '2015_156': 'TAUBATE',
#  '2015_157': 'VOTUPORANGA',
#  '2015_158': 'JALES',
#  '2015_159': 'VALPARAISO',
#  '2015_160': 'JOSE BONIFACIO',
#  '2015_161': 'ARIRANHA',
#  '2015_162': 'IBITINGA',
#  '2015_163': 'CASA BRANCA',
#  '2015_164': 'ITAPIRA',
#  '2015_165': 'SAO LUIS DO PARAITINGA',
#  '2015_166': 'BARRA BONITA',
#  '2015_167': 'BARRA DO TURVO',
#  '2015_168': 'PRADOPOLIS',
#  '2015_169': 'BARRETOS',
#  '2015_170': 'ITUVERAVA',
#  '2015_171': 'BARUERI',
#  '2016_152': 'SAO PAULO - MIRANTE',
#  '2016_153': 'BAURU',
#  '2016_154': 'CAMPOS DO JORDAO',
#  '2016_155': 'PRESIDENTE PRUDENTE',
#  '2016_156': 'FRANCA',
#  '2016_157': 'SAO CARLOS',
#  '2016_158': 'IGUAPE',
#  '2016_159': 'SOROCABA',
#  '2016_160': 'ITAPEVA',
#  '2016_161': 'SAO MIGUEL ARCANJO',
#  '2016_162': 'OURINHOS',
#  '2016_163': 'RANCHARIA',
#  '2016_164': 'AVARE',
#  '2016_165': 'PIRACICABA',
#  '2016_166': 'LINS',
#  '2016_167': 'TAUBATE',
#  '2016_168': 'VOTUPORANGA',
#  '2016_169': 'JALES',
#  '2016_170': 'VALPARAISO',
#  '2016_171': 'JOSE BONIFACIO',
#  '2016_172': 'ARIRANHA',
#  '2016_173': 'IBITINGA',
#  '2016_174': 'CASA BRANCA',
#  '2016_175': 'ITAPIRA',
#  '2016_176': 'SAO LUIS DO PARAITINGA',
#  '2016_177': 'BARRA BONITA',
#  '2016_178': 'BARRA DO TURVO',
#  '2016_179': 'PRADOPOLIS',
#  '2016_180': 'BARRETOS',
#  '2016_181': 'ITUVERAVA',
#  '2016_182': 'BARUERI',
#  '2016_183': 'DRACENA',
#  '2016_184': 'BEBDOURO',
#  '2017_165': 'SAO PAULO - MIRANTE',
#  '2017_166': 'BAURU',
#  '2017_167': 'CAMPOS DO JORDAO',
#  '2017_168': 'PRESIDENTE PRUDENTE',
#  '2017_169': 'FRANCA',
#  '2017_170': 'SAO CARLOS',
#  '2017_171': 'IGUAPE',
#  '2017_172': 'SOROCABA',
#  '2017_173': 'ITAPEVA',
#  '2017_174': 'SAO MIGUEL ARCANJO',
#  '2017_175': 'OURINHOS',
#  '2017_176': 'RANCHARIA',
#  '2017_177': 'AVARE',
#  '2017_178': 'PIRACICABA',
#  '2017_179': 'LINS',
#  '2017_180': 'TAUBATE',
#  '2017_181': 'VOTUPORANGA',
#  '2017_182': 'JALES',
#  '2017_183': 'VALPARAISO',
#  '2017_184': 'JOSE BONIFACIO',
#  '2017_185': 'ARIRANHA',
#  '2017_186': 'IBITINGA',
#  '2017_187': 'CASA BRANCA',
#  '2017_188': 'ITAPIRA',
#  '2017_189': 'SAO LUIS DO PARAITINGA',
#  '2017_190': 'BARRA BONITA',
#  '2017_191': 'BRAGANCA PAULISTA',
#  '2017_192': 'BARRA DO TURVO',
#  '2017_193': 'PRADOPOLIS',
#  '2017_194': 'BARRETOS',
#  '2017_195': 'ITUVERAVA',
#  '2017_196': 'BARUERI',
#  '2017_197': 'DRACENA',
#  '2017_198': 'MARILIA',
#  '2017_199': 'BEBDOURO',
#  '2017_200': 'BERTIOGA',
#  '2017_201': 'REGISTRO',
#  '2017_202': 'SAO SEBASTIAO',
#  '2017_203': 'TUPA',
#  '2017_204': 'CACHOEIRA PAULISTA',
#  '2018_173': 'SAO PAULO - MIRANTE',
#  '2018_174': 'BAURU',
#  '2018_175': 'CAMPOS DO JORDAO',
#  '2018_176': 'PRESIDENTE PRUDENTE',
#  '2018_177': 'FRANCA',
#  '2018_178': 'SAO CARLOS',
#  '2018_179': 'IGUAPE',
#  '2018_180': 'SOROCABA',
#  '2018_181': 'ITAPEVA',
#  '2018_182': 'SAO MIGUEL ARCANJO',
#  '2018_183': 'OURINHOS',
#  '2018_184': 'RANCHARIA',
#  '2018_185': 'AVARE',
#  '2018_186': 'PIRACICABA',
#  '2018_187': 'LINS',
#  '2018_188': 'TAUBATE',
#  '2018_189': 'VOTUPORANGA',
#  '2018_190': 'JALES',
#  '2018_191': 'VALPARAISO',
#  '2018_192': 'JOSE BONIFACIO',
#  '2018_193': 'ARIRANHA',
#  '2018_194': 'IBITINGA',
#  '2018_195': 'CASA BRANCA',
#  '2018_196': 'ITAPIRA',
#  '2018_197': 'SAO LUIS DO PARAITINGA',
#  '2018_198': 'BARRA BONITA',
#  '2018_199': 'BRAGANCA PAULISTA',
#  '2018_200': 'BARRA DO TURVO',
#  '2018_201': 'PRADOPOLIS',
#  '2018_202': 'BARRETOS',
#  '2018_203': 'ITUVERAVA',
#  '2018_204': 'BARUERI',
#  '2018_205': 'DRACENA',
#  '2018_206': 'MARILIA',
#  '2018_207': 'BEBDOURO',
#  '2018_208': 'BERTIOGA',
#  '2018_209': 'REGISTRO',
#  '2018_210': 'SAO SEBASTIAO',
#  '2018_211': 'TUPA',
#  '2018_212': 'CACHOEIRA PAULISTA',
#  '2018_213': 'SAO PAULO - INTERLAGOS',
#  '2019_171': 'SAO PAULO - MIRANTE',
#  '2019_172': 'BAURU',
#  '2019_173': 'CAMPOS DO JORDAO',
#  '2019_174': 'PRESIDENTE PRUDENTE',
#  '2019_175': 'FRANCA',
#  '2019_176': 'SAO CARLOS',
#  '2019_177': 'IGUAPE',
#  '2019_178': 'SOROCABA',
#  '2019_179': 'ITAPEVA',
#  '2019_180': 'SAO MIGUEL ARCANJO',
#  '2019_181': 'OURINHOS',
#  '2019_182': 'RANCHARIA',
#  '2019_183': 'AVARE',
#  '2019_184': 'PIRACICABA',
#  '2019_185': 'LINS',
#  '2019_186': 'TAUBATE',
#  '2019_187': 'VOTUPORANGA',
#  '2019_188': 'JALES',
#  '2019_189': 'VALPARAISO',
#  '2019_190': 'JOSE BONIFACIO',
#  '2019_191': 'ARIRANHA',
#  '2019_192': 'IBITINGA',
#  '2019_193': 'CASA BRANCA',
#  '2019_194': 'ITAPIRA',
#  '2019_195': 'SAO LUIS DO PARAITINGA',
#  '2019_196': 'BARRA BONITA',
#  '2019_197': 'BRAGANCA PAULISTA',
#  '2019_198': 'BARRA DO TURVO',
#  '2019_199': 'PRADOPOLIS',
#  '2019_200': 'BARRETOS',
#  '2019_201': 'ITUVERAVA',
#  '2019_202': 'BARUERI',
#  '2019_203': 'DRACENA',
#  '2019_204': 'MARILIA',
#  '2019_205': 'BEBDOURO',
#  '2019_206': 'BERTIOGA',
#  '2019_207': 'REGISTRO',
#  '2019_208': 'SAO SEBASTIAO',
#  '2019_209': 'TUPA',
#  '2019_210': 'CACHOEIRA PAULISTA',
#  '2019_211': 'SAO SIMAO',
#  '2019_212': 'SAO PAULO - INTERLAGOS',
#  '2020_171': 'SAO PAULO - MIRANTE',
#  '2020_172': 'BAURU',
#  '2020_173': 'CAMPOS DO JORDAO',
#  '2020_174': 'PRESIDENTE PRUDENTE',
#  '2020_175': 'FRANCA',
#  '2020_176': 'SAO CARLOS',
#  '2020_177': 'IGUAPE',
#  '2020_178': 'SOROCABA',
#  '2020_179': 'ITAPEVA',
#  '2020_180': 'SAO MIGUEL ARCANJO',
#  '2020_181': 'OURINHOS',
#  '2020_182': 'RANCHARIA',
#  '2020_183': 'AVARE',
#  '2020_184': 'PIRACICABA',
#  '2020_185': 'LINS',
#  '2020_186': 'TAUBATE',
#  '2020_187': 'VOTUPORANGA',
#  '2020_188': 'JALES',
#  '2020_189': 'VALPARAISO',
#  '2020_190': 'JOSE BONIFACIO',
#  '2020_191': 'ARIRANHA',
#  '2020_192': 'IBITINGA',
#  '2020_193': 'CASA BRANCA',
#  '2020_194': 'ITAPIRA',
#  '2020_195': 'SAO LUIS DO PARAITINGA',
#  '2020_196': 'BARRA BONITA',
#  '2020_197': 'BRAGANCA PAULISTA',
#  '2020_198': 'BARRA DO TURVO',
#  '2020_199': 'PRADOPOLIS',
#  '2020_200': 'BARRETOS',
#  '2020_201': 'ITUVERAVA',
#  '2020_202': 'BARUERI',
#  '2020_203': 'DRACENA',
#  '2020_204': 'MARILIA',
#  '2020_205': 'BEBDOURO',
#  '2020_206': 'BERTIOGA',
#  '2020_207': 'REGISTRO',
#  '2020_208': 'SAO SEBASTIAO',
#  '2020_209': 'TUPA',
#  '2020_210': 'CACHOEIRA PAULISTA',
#  '2020_211': 'SAO SIMAO',
#  '2020_212': 'SAO PAULO - INTERLAGOS',
#  '2020_213': 'CRIOSFERA',
#  '2021_172': 'SAO PAULO - MIRANTE',
#  '2021_173': 'BAURU',
#  '2021_174': 'CAMPOS DO JORDAO',
#  '2021_175': 'PRESIDENTE PRUDENTE',
#  '2021_176': 'FRANCA',
#  '2021_177': 'SAO CARLOS',
#  '2021_178': 'IGUAPE',
#  '2021_179': 'SOROCABA',
#  '2021_180': 'ITAPEVA',
#  '2021_181': 'SAO MIGUEL ARCANJO',
#  '2021_182': 'OURINHOS',
#  '2021_183': 'RANCHARIA',
#  '2021_184': 'AVARE',
#  '2021_185': 'PIRACICABA',
#  '2021_186': 'LINS',
#  '2021_187': 'TAUBATE',
#  '2021_188': 'VOTUPORANGA',
#  '2021_189': 'JALES',
#  '2021_190': 'VALPARAISO',
#  '2021_191': 'JOSE BONIFACIO',
#  '2021_192': 'ARIRANHA',
#  '2021_193': 'IBITINGA',
#  '2021_194': 'CASA BRANCA',
#  '2021_195': 'ITAPIRA',
#  '2021_196': 'SAO LUIS DO PARAITINGA',
#  '2021_197': 'BARRA BONITA',
#  '2021_198': 'BRAGANCA PAULISTA',
#  '2021_199': 'BARRA DO TURVO',
#  '2021_200': 'PRADOPOLIS',
#  '2021_201': 'BARRETOS',
#  '2021_202': 'ITUVERAVA',
#  '2021_203': 'BARUERI',
#  '2021_204': 'DRACENA',
#  '2021_205': 'MARILIA',
#  '2021_206': 'BEBEDOURO',
#  '2021_207': 'BERTIOGA',
#  '2021_208': 'REGISTRO',
#  '2021_209': 'SAO SEBASTIAO',
#  '2021_210': 'TUPA',
#  '2021_211': 'CACHOEIRA PAULISTA',
#  '2021_212': 'SAO SIMAO',
#  '2021_213': 'SAO PAULO - INTERLAGOS',
#  '2022_171': 'SAO PAULO - MIRANTE',
#  '2022_172': 'BAURU',
#  '2022_173': 'CAMPOS DO JORDAO',
#  '2022_174': 'PRESIDENTE PRUDENTE',
#  '2022_175': 'FRANCA',
#  '2022_176': 'SAO CARLOS',
#  '2022_177': 'IGUAPE',
#  '2022_178': 'SOROCABA',
#  '2022_179': 'ITAPEVA',
#  '2022_180': 'SAO MIGUEL ARCANJO',
#  '2022_181': 'RANCHARIA',
#  '2022_182': 'AVARE',
#  '2022_183': 'PIRACICABA',
#  '2022_184': 'LINS',
#  '2022_185': 'TAUBATE',
#  '2022_186': 'JALES',
#  '2022_187': 'VALPARAISO',
#  '2022_188': 'JOSE BONIFACIO',
#  '2022_189': 'ARIRANHA',
#  '2022_190': 'IBITINGA',
#  '2022_191': 'CASA BRANCA',
#  '2022_192': 'ITAPIRA',
#  '2022_193': 'SAO LUIZ DO PARAITINGA',
#  '2022_194': 'BARRA BONITA',
#  '2022_195': 'BRAGANCA PAULISTA',
#  '2022_196': 'BARRA DO TURVO',
#  '2022_197': 'PRADOPOLIS',
#  '2022_198': 'BARRETOS',
#  '2022_199': 'ITUVERAVA',
#  '2022_200': 'BARUERI',
#  '2022_201': 'DRACENA',
#  '2022_202': 'MARILIA',
#  '2022_203': 'BERTIOGA',
#  '2022_204': 'REGISTRO',
#  '2022_205': 'TUPA',
#  '2022_206': 'CACHOEIRA PAULISTA',
#  '2022_207': 'SAO SIMAO',
#  '2022_208': 'SAO PAULO - INTERLAGOS',
#  '2023_169': 'SAO PAULO - MIRANTE',
#  '2023_170': 'BAURU',
#  '2023_171': 'CAMPOS DO JORDAO',
#  '2023_172': 'PRESIDENTE PRUDENTE',
#  '2023_173': 'FRANCA',
#  '2023_174': 'SAO CARLOS',
#  '2023_175': 'IGUAPE',
#  '2023_176': 'SOROCABA',
#  '2023_177': 'ITAPEVA',
#  '2023_178': 'SAO MIGUEL ARCANJO',
#  '2023_179': 'OURINHOS',
#  '2023_180': 'RANCHARIA',
#  '2023_181': 'AVARE',
#  '2023_182': 'PIRACICABA',
#  '2023_183': 'LINS',
#  '2023_184': 'TAUBATE',
#  '2023_185': 'JALES',
#  '2023_186': 'VALPARAISO',
#  '2023_187': 'JOSE BONIFACIO',
#  '2023_188': 'ARIRANHA',
#  '2023_189': 'IBITINGA',
#  '2023_190': 'CASA BRANCA',
#  '2023_191': 'ITAPIRA',
#  '2023_192': 'SAO LUIZ DO PARAITINGA',
#  '2023_193': 'BARRA BONITA',
#  '2023_194': 'BRAGANCA PAULISTA',
#  '2023_195': 'BARRA DO TURVO',
#  '2023_196': 'PRADOPOLIS',
#  '2023_197': 'BARRETOS',
#  '2023_198': 'ITUVERAVA',
#  '2023_199': 'BARUERI',
#  '2023_200': 'DRACENA',
#  '2023_201': 'MARILIA',
#  '2023_202': 'BEBEDOURO',
#  '2023_203': 'BERTIOGA',
#  '2023_204': 'REGISTRO',
#  '2023_205': 'TUPA',
#  '2023_206': 'CACHOEIRA PAULISTA',
#  '2023_207': 'SAO SIMAO',
#  '2023_208': 'SAO PAULO - INTERLAGOS'}

# %% [markdown]
# ##### Passos 4 e 5 - importar e tratar o banco de dados:

# %%
user_yr = input('Digite o ano ')
user_city = input('Digite a cidade ').replace('-', r'\-').replace('(', r'\(').replace(')', r'\)').upper()
user_yr_list = os.listdir(f'assets/{user_yr}/')
for file in user_yr_list:
    if re.search(f'{user_city}', file) != None:
        city_data = pd.read_csv(f'assets/{user_yr}/{file}', skiprows=8, encoding='latin-1', on_bad_lines='skip', sep=';', usecols=[0,7,15,18])
        city_data.rename(columns={city_data.iloc[:, 0].name: 'Data'}, inplace=True)
        city_data['Data'] = pd.to_datetime(city_data['Data'])
        city_data['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = city_data['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].str.replace(',', '.').str.replace('-9999', 'NaN').astype(float)
        city_data['UMIDADE RELATIVA DO AR, HORARIA (%)'] = city_data['UMIDADE RELATIVA DO AR, HORARIA (%)'].replace(',', '.').replace(-9999, 'NaN').astype(float)
        city_data['VENTO, VELOCIDADE HORARIA (m/s)'] = city_data['VENTO, VELOCIDADE HORARIA (m/s)'].str.replace(',', '.').str.replace('-9999', 'NaN').astype(float)
        display(city_data)
# Out:
#            Data  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0    2023-01-01                                          20.6
# 1    2023-01-01                                          20.1
# 2    2023-01-01                                          19.9
# 3    2023-01-01                                          19.6
# 4    2023-01-01                                          19.3
# ...         ...                                           ...
# 7291 2023-10-31                                          27.5
# 7292 2023-10-31                                          25.8
# 7293 2023-10-31                                          21.0
# 7294 2023-10-31                                          20.3
# 7295 2023-10-31                                          20.4
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, VELOCIDADE HORARIA (m/s)
# 0                                    85.0                              1.7
# 1                                    89.0                              1.3
# 2                                    90.0                              1.3
# 3                                    91.0                              0.4
# 4                                    91.0                              0.5
# ...                                   ...                              ...
# 7291                                 52.0                              2.0
# 7292                                 62.0                              1.6
# 7293                                 82.0                              4.3
# 7294                                 89.0                              2.4
# 7295                                 89.0                              2.0
#
# [7296 rows x 4 columns]

# %%
display(city_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7296 entries, 0 to 7295
# Data columns (total 4 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Data                                          7296 non-null   datetime64[ns]
#  1   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  7296 non-null   float64
#  2   UMIDADE RELATIVA DO AR, HORARIA (%)           7296 non-null   float64
#  3   VENTO, VELOCIDADE HORARIA (m/s)               7296 non-null   float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 228.1 KB
# None

# %%
city_table = city_data.groupby('Data').mean()
display(city_table)
# Out:
#             TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# Data
# 2023-01-01                                     21.329167
# 2023-01-02                                     20.983333
# 2023-01-03                                     20.775000
# 2023-01-04                                     20.845833
# 2023-01-05                                     20.270833
# ...                                                  ...
# 2023-10-27                                     22.779167
# 2023-10-28                                     23.912500
# 2023-10-29                                     25.812500
# 2023-10-30                                     24.470833
# 2023-10-31                                     24.250000
#
#             UMIDADE RELATIVA DO AR, HORARIA (%)  \
# Data
# 2023-01-01                            83.208333
# 2023-01-02                            83.250000
# 2023-01-03                            85.916667
# 2023-01-04                            87.375000
# 2023-01-05                            90.833333
# ...                                         ...
# 2023-10-27                            80.791667
# 2023-10-28                            75.583333
# 2023-10-29                            68.875000
# 2023-10-30                            75.708333
# 2023-10-31                            71.583333
#
#             VENTO, VELOCIDADE HORARIA (m/s)
# Data
# 2023-01-01                         1.362500
# 2023-01-02                         1.437500
# 2023-01-03                         1.150000
# 2023-01-04                         1.029167
# 2023-01-05                         0.466667
# ...                                     ...
# 2023-10-27                         1.283333
# 2023-10-28                         1.333333
# 2023-10-29                         1.183333
# 2023-10-30                         1.166667
# 2023-10-31                         1.754167
#
# [304 rows x 3 columns]

# %% [markdown]
# ##### 6. Agrupar os dados de mês em mês:

# %%
city_table = city_data.groupby(pd.Grouper(key='Data',axis=0, freq='M')).mean()

city_table.reset_index(inplace=True)
display(city_table)
# Out:
#         Data  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0 2023-01-31                                     22.116398
# 1 2023-02-28                                     24.002679
# 2 2023-03-31                                     24.180645
# 3 2023-04-30                                     22.113472
# 4 2023-05-31                                     20.025538
# 5 2023-06-30                                     18.713889
# 6 2023-07-31                                     19.483871
# 7 2023-08-31                                     21.232258
# 8 2023-09-30                                     24.017917
# 9 2023-10-31                                     24.763978
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, VELOCIDADE HORARIA (m/s)
# 0                            79.841398                         1.218414
# 1                            68.363095                         1.483036
# 2                            62.973118                         1.606989
# 3                            70.718056                         1.501667
# 4                            66.086022                         1.334140
# 5                            64.847222                         1.134861
# 6                            61.110215                         1.462769
# 7                            59.000000                         1.563844
# 8                            55.284722                         2.152917
# 9                            65.067204                         1.697312

# %% [markdown]
# ##### 7. Tratar os nomes das linhas, definindo o mês em questão:

# %%
i=0
for month in ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']:
    city_table['Data'][i] = f'{month}/{user_yr[2:]}'
    i+=1

display(city_table['Data'])
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_13140\3167603848.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city_table['Data'][i] = f'{month}/{user_yr[2:]}'
# C:\Users\henri\AppData\Local\Temp\ipykernel_13140\3167603848.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Jan/23' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   city_table['Data'][i] = f'{month}/{user_yr[2:]}'
# C:\Users\henri\AppData\Local\Temp\ipykernel_13140\3167603848.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city_table['Data'][i] = f'{month}/{user_yr[2:]}'
# 0    Jan/23
# 1    Fev/23
# 2    Mar/23
# 3    Abr/23
# 4    Mai/23
# 5    Jun/23
# 6    Jul/23
# 7    Ago/23
# 8    Set/23
# 9    Out/23
# Name: Data, dtype: object

# %% [markdown]
# ##### 8. Criar e exibir o gráfico interativo:

# %%
city_table.dropna(inplace=True)
fig = go.Figure(
    data=[go.Scatter(x=city_table['Data'], y=city_table['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'])],
    skip_invalid=True,
    empty=False,
    layout = go.Layout(title=go.layout.Title(text=f'Temperatura média/mês no ano de {user_yr} em {user_city.title()}'))
    )
fig.update_layout(xaxis_title_text=f'Meses do ano', yaxis_title_text='Temperatura média (ºC)')
fig.show()
